# %% [markdown]
# ## 切分音频

# %%
from pydub import AudioSegment
import math
import os

# 指定FFmpeg的路径
ffmpeg_path = r"E:\Software\ffmpeg-master-latest-win64-gpl\bin"
os.environ["PATH"] += os.pathsep + ffmpeg_path

def split_audio(file_path, segment_length_ms):
    audio = AudioSegment.from_file(file_path)
    duration_ms = len(audio)
    segments_count = math.ceil(duration_ms / segment_length_ms)

    for i in range(segments_count):
        start_ms = i * segment_length_ms
        end_ms = min((i + 1) * segment_length_ms, duration_ms)
        segment = audio[start_ms:end_ms]
        segment.export(f"segment_{i}.mp3", format="mp3")

# 使用示例
file_path = "FC2PPV-2953018.mp3"  # 你的音频文件路径
segment_length_ms = 20 * 60 * 1000  # 每个片段的长度，这里设置为30秒
split_audio(file_path, segment_length_ms)

# %% [markdown]
# ## 生成字幕

# %%
def generate_corrected_transcript(temperature, system_prompt, text):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-16k",
        temperature=temperature,
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content":  text
            }
        ],
    )
    # print(response)
    # print(type(response))
    return response.choices[0].message.content

# %%
from openai import OpenAI
import os

# os.environ['OPENAI_BASE_URL'] = 'https://www.api.rovy.me/v1'
os.environ['OPENAI_API_KEY'] = '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'

# 音频翻译成英文
from openai import OpenAI
client = OpenAI()

import glob

# 获取当前目录下所有以 'segment_' 开头的 .mp3 文件
segment_files = glob.glob('segment_*.mp3')

isTranslate = True
# 遍历文件列表
for filename in segment_files:
    with open(filename, "rb") as audio_file:
        translate = client.audio.translations.create(
            model="whisper-1",
            file=audio_file,
            response_format="srt",
        )
        # 根据音频文件名生成SRT文件名
    srt_filename = filename.replace('.mp3', '.srt')


    # 存储翻译结果到SRT文件
    with open(srt_filename, "w") as f:
        f.write(translate)

    print(f"Translation for {filename} saved to {srt_filename}")
    try:
        if isTranslate:
            system_prompt = "You are a helpful assistant for processing transcript. Your task is to translate the following text to Chinese. Additionally, pay attention to capturing the emotional exchanges and tone variations between characters, ensuring the translation is faithful to the source material while also conveying the same emotions and narrative atmosphere to an Chinese-speaking audience.The output must strictly follow the srt format."
            translate_cn = generate_corrected_transcript(0, system_prompt, translate)
            srt_filename_cn = filename.replace('.mp3', '_cn.srt')
            with open('./cn/' + srt_filename_cn, "w", encoding='UTF-8') as f:
                f.write(translate_cn)
                print(f"{srt_filename} -- 英文字幕转中文字幕成功")
    except:
        print(f"{srt_filename} -- 英文字幕转中文字幕失败")
# Out:
# Translation for segment_0.mp3 saved to segment_0.srt
# <class 'openai.types.chat.chat_completion.ChatCompletion'>
# segment_0.srt -- 英文字幕转中文字幕成功
# Translation for segment_1.mp3 saved to segment_1.srt
# <class 'openai.types.chat.chat_completion.ChatCompletion'>
# segment_1.srt -- 英文字幕转中文字幕成功
# Translation for segment_2.mp3 saved to segment_2.srt
# <class 'openai.types.chat.chat_completion.ChatCompletion'>
# segment_2.srt -- 英文字幕转中文字幕成功

# %% [markdown]
# ## 合成字幕文件

# %%
import re
from datetime import datetime, timedelta
import glob

def str_to_timedelta(time_str):
    return datetime.strptime(time_str, '%H:%M:%S,%f') - datetime(1900, 1, 1)

def timedelta_to_str(time_delta):
    hours, remainder = divmod(time_delta.total_seconds(), 3600)
    minutes, seconds = divmod(remainder, 60)
    return "{:02}:{:02}:{:06.3f}".format(int(hours), int(minutes), seconds).replace('.', ',')

def adjust_subtitle_time(subtitle, time_offset):
    try:
        time_pattern = re.compile(r'(\d{2}:\d{2}:\d{2},\d{3}) --> (\d{2}:\d{2}:\d{2},\d{3})')
        start_time_str, end_time_str = time_pattern.search(subtitle).groups()
        start_time = str_to_timedelta(start_time_str) + time_offset
        end_time = str_to_timedelta(end_time_str) + time_offset
        adjusted_subtitle = re.sub(time_pattern, f'{timedelta_to_str(start_time)} --> {timedelta_to_str(end_time)}', subtitle)
        return adjusted_subtitle
    except:
        return subtitle

def merge_subtitles(subtitle_files, video_durations):
    merged_subtitle = ""
    time_offset = timedelta()
    subtitle_index = 1

    for subtitle_file, duration in zip(subtitle_files, video_durations):
        # print(subtitle_file, duration)
        with open(subtitle_file, 'r', encoding='utf-8') as f:  # Use UTF-8 encoding
            subtitles = f.read().strip().split('\n\n')
            for subtitle in subtitles:
                print(subtitle)
                if not subtitle.strip():
                    continue
                adjusted_subtitle = adjust_subtitle_time(subtitle, time_offset)
                adjusted_subtitle = re.sub(r'^\d+', str(subtitle_index), adjusted_subtitle, count=1)
                merged_subtitle += adjusted_subtitle + "\n\n"
                subtitle_index += 1
        time_offset += timedelta(seconds=duration)

    return merged_subtitle.strip()

# 示例使用 glob 查找文件和假定的视频持续时间
subtitle_files = glob.glob('segment*.srt')
subtitle_files.sort()  # 确保按顺序处理文件

video_durations = [20 * 60 for _ in subtitle_files]  # 假设每段视频20分钟

merged_subtitle = merge_subtitles(subtitle_files, video_durations)

# 保存合并后的字幕文件
with open('merged_subtitle-0207.srt', 'w', encoding='utf-8') as f:
    f.write(merged_subtitle)

if isTranslate:
    subtitle_files_cn = glob.glob('./cn/segment*.srt')
    subtitle_files_cn.sort()  # 确保按顺序处理文件

    video_durations_cn = [20 * 60 for _ in subtitle_files_cn]  # 假设每段视频20分钟
    # print(subtitle_files_cn)
    # print(video_durations_cn)
    merged_subtitle_cn = merge_subtitles(subtitle_files_cn, video_durations_cn)

    # 保存合并后的字幕文件
    with open('./cn/merged_subtitle-0207_cn.srt', 'w', encoding='utf-8') as f:
        f.write(merged_subtitle_cn)
try:
    if isTranslate:
        subtitle_files_cn = glob.glob('./cn/segment*.srt')
        subtitle_files_cn.sort()  # 确保按顺序处理文件

        video_durations_cn = [20 * 60 for _ in subtitle_files_cn]  # 假设每段视频20分钟

        merged_subtitle_cn = merge_subtitles(subtitle_files_cn, video_durations_cn)

        # 保存合并后的字幕文件
        with open('./cn/merged_subtitle-0207_cn.srt', 'w', encoding='utf-8') as f:
            f.write(merged_subtitle_cn)
except Exception as E:
    # 打印错误信息
    print(E)
    print(f"中文字幕合并失败")
# Out:
# 1
# 00:00:00,000 --> 00:00:22,400
# I'm.
# 2
# 00:00:22,400 --> 00:00:39,759
# He has a brown nose.
# 3
# 00:00:39,759 --> 00:00:47,919
# Now let's ask him a few questions.
# 4
# 00:00:47,919 --> 00:00:54,919
# First, let's ask him how he feels about his new hair color.
# 5
# 00:00:54,919 --> 00:01:01,919
# I'm not sure how he feels about his new hair color, so I'm going to ask him a few questions.
# 6
# 00:01:01,919 --> 00:01:06,919
# First, let's ask him how he feels about his new hair color.
# 7
# 00:01:06,919 --> 00:01:07,919
# Hello.
# 8
# 00:01:07,919 --> 00:01:08,919
# What?
# 9
# 00:01:08,919 --> 00:01:09,919
# Hello.
# 10
# 00:01:09,919 --> 00:01:10,919
# Hello.
# 11
# 00:01:10,919 --> 00:01:18,919
# You always look beautiful.
# 12
# 00:01:18,919 --> 00:01:20,919
# Thank you.
# 13
# 00:01:20,919 --> 00:01:22,919
# Do people say that a lot?
# 14
# 00:01:22,919 --> 00:01:24,919
# No, they don't.
# 15
# 00:01:24,919 --> 00:01:25,919
# They don't?
# 16
# 00:01:25,919 --> 00:01:26,919
# No.
# 17
# 00:01:26,919 --> 00:01:33,919
# What did you come here for today?
# 18
# 00:01:33,919 --> 00:01:36,919
# I came here to hang out.
# 19
# 00:01:36,919 --> 00:01:37,919
# To hang out?
# 20
# 00:01:37,919 --> 00:01:38,919
# Yes.
# 21
# 00:01:39,919 --> 00:01:44,919
# What kind of hang out?
# 22
# 00:01:44,919 --> 00:01:48,919
# Fun hang out.
# 23
# 00:01:48,919 --> 00:01:51,919
# You look like you're having fun.
# 24
# 00:01:51,919 --> 00:01:53,919
# I look like I'm having fun.
# 25
# 00:01:53,919 --> 00:01:58,919
# What kind of people are there?
# 26
# 00:01:58,919 --> 00:02:06,919
# Tall people.
# 27
# 00:02:06,919 --> 00:02:09,919
# People with masks.
# 28
# 00:02:09,919 --> 00:02:11,919
# Are they suspicious?
# 29
# 00:02:11,919 --> 00:02:12,919
# Suspicious.
# 30
# 00:02:12,919 --> 00:02:13,919
# Suspicious?
# 31
# 00:02:13,919 --> 00:02:14,919
# Yes.
# 32
# 00:02:14,919 --> 00:02:19,919
# Then, I'm going to ask you something fun.
# 33
# 00:02:19,919 --> 00:02:20,919
# Yes.
# 34
# 00:02:20,919 --> 00:02:21,919
# Are you ready?
# 35
# 00:02:21,919 --> 00:02:22,919
# Yes.
# 36
# 00:02:22,919 --> 00:02:25,919
# Go ahead.
# 37
# 00:02:25,919 --> 00:02:26,919
# Hello.
# 38
# 00:02:26,919 --> 00:02:27,919
# Hello.
# 39
# 00:02:27,919 --> 00:02:28,919
# You're a suspicious person.
# 40
# 00:02:28,919 --> 00:02:29,919
# Yes, I am.
# 41
# 00:02:29,919 --> 00:02:31,919
# You're so cute.
# 42
# 00:02:31,919 --> 00:02:33,919
# Thank you.
# 43
# 00:02:33,919 --> 00:02:35,919
# How old are you?
# 44
# 00:02:35,919 --> 00:02:36,919
# I'm 22 years old.
# 45
# 00:02:36,919 --> 00:02:37,919
# 22 years old.
# 46
# 00:02:37,919 --> 00:02:38,919
# I see.
# 47
# 00:02:38,919 --> 00:02:41,919
# What does that mean?
# 48
# 00:02:41,919 --> 00:02:42,919
# Are you a social worker?
# 49
# 00:02:42,919 --> 00:02:44,919
# I'm a fourth-year university student.
# 50
# 00:02:44,919 --> 00:02:45,919
# A fourth-year university student?
# 51
# 00:02:45,919 --> 00:02:46,919
# Yes.
# 52
# 00:02:46,919 --> 00:02:54,919
# I didn't know you had so much fun when you were a fourth-year university student.
# 53
# 00:02:54,919 --> 00:02:57,919
# You're a bit of a show-off, aren't you?
# 54
# 00:02:57,919 --> 00:02:58,919
# A bit.
# 55
# 00:02:58,919 --> 00:02:59,919
# Just a bit?
# 56
# 00:02:59,919 --> 00:03:00,919
# Yes.
# 57
# 00:03:01,919 --> 00:03:02,919
# I see.
# 58
# 00:03:02,919 --> 00:03:10,919
# If you're such a beautiful girl, a lot of boys will come to you even if you don't play like this.
# 59
# 00:03:10,919 --> 00:03:12,919
# No, they won't.
# 60
# 00:03:12,919 --> 00:03:13,919
# What?
# 61
# 00:03:13,919 --> 00:03:16,919
# I don't think there are any eyes around you.
# 62
# 00:03:16,919 --> 00:03:17,919
# I see.
# 63
# 00:03:17,919 --> 00:03:19,919
# No.
# 64
# 00:03:19,919 --> 00:03:25,919
# Then, today, I'm going to talk to a boy who has no eyes.
# 65
# 00:03:25,919 --> 00:03:27,919
# Yes.
# 66
# 00:03:28,919 --> 00:03:30,919
# Your skin is really white and beautiful.
# 67
# 00:03:30,919 --> 00:03:32,919
# It's dirty.
# 68
# 00:03:32,919 --> 00:03:33,919
# Why?
# 69
# 00:03:33,919 --> 00:03:35,919
# Why are you not so confident?
# 70
# 00:03:35,919 --> 00:03:37,919
# I'm not confident.
# 71
# 00:03:39,919 --> 00:03:41,919
# You're so cute.
# 72
# 00:03:41,919 --> 00:03:42,919
# Yes.
# 73
# 00:03:47,919 --> 00:03:50,919
# Your lips are small and cute.
# 74
# 00:03:57,919 --> 00:03:58,919
# Yes.
# 75
# 00:04:57,920 --> 00:04:59,920
# Your lips are so soft.
# 76
# 00:05:02,920 --> 00:05:04,920
# How many boys do you have?
# 77
# 00:05:04,920 --> 00:05:05,920
# Not many.
# 78
# 00:05:05,920 --> 00:05:06,920
# What?
# 79
# 00:05:06,920 --> 00:05:07,920
# Not many.
# 80
# 00:05:07,920 --> 00:05:08,920
# Not many?
# 81
# 00:05:08,920 --> 00:05:09,920
# Yes.
# 82
# 00:05:09,920 --> 00:05:10,920
# About five?
# 83
# 00:05:10,920 --> 00:05:12,920
# I don't know.
# 84
# 00:05:12,920 --> 00:05:13,920
# You don't know?
# 85
# 00:05:14,920 --> 00:05:16,920
# I wonder how many boys you have.
# 86
# 00:05:17,920 --> 00:05:20,920
# So, you only know boys.
# 87
# 00:05:21,920 --> 00:05:22,920
# I see.
# 88
# 00:05:24,920 --> 00:05:26,920
# I'm getting excited.
# 89
# 00:05:28,920 --> 00:05:30,920
# You have a good style.
# 90
# 00:05:31,920 --> 00:05:33,920
# You have a tight body.
# 91
# 00:05:35,920 --> 00:05:37,920
# You have a lot of boobs.
# 92
# 00:05:43,920 --> 00:05:45,920
# What kind of style do you like?
# 93
# 00:05:47,920 --> 00:05:48,920
# What?
# 94
# 00:05:49,920 --> 00:05:51,920
# Do you feel something in your chest?
# 95
# 00:05:52,920 --> 00:05:53,920
# I like a gentle style.
# 96
# 00:05:53,920 --> 00:05:55,920
# A gentle style?
# 97
# 00:05:55,920 --> 00:05:56,920
# Don't worry.
# 98
# 00:05:56,920 --> 00:05:58,920
# I have a gentle style.
# 99
# 00:06:01,920 --> 00:06:03,920
# Do you have any other sensitive spots?
# 100
# 00:06:04,920 --> 00:06:06,920
# Like ears or neck?
# 101
# 00:06:07,920 --> 00:06:08,920
# It tickles.
# 102
# 00:06:08,920 --> 00:06:09,920
# What?
# 103
# 00:06:09,920 --> 00:06:10,920
# Really?
# 104
# 00:06:10,920 --> 00:06:11,920
# Yes.
# 105
# 00:06:11,920 --> 00:06:13,920
# Let me check your neck.
# 106
# 00:06:19,920 --> 00:06:20,920
# It tickles.
# 107
# 00:06:20,920 --> 00:06:22,920
# Does it tickle?
# 108
# 00:06:22,920 --> 00:06:24,920
# Does it tickle?
# 109
# 00:06:24,920 --> 00:06:25,920
# It tickles.
# 110
# 00:06:29,920 --> 00:06:31,920
# You are cute.
# 111
# 00:06:33,920 --> 00:06:34,920
# By the way,
# 112
# 00:06:36,920 --> 00:06:39,920
# What kind of underwear are you wearing today?
# 113
# 00:06:42,920 --> 00:06:43,920
# How should I put it?
# 114
# 00:06:43,920 --> 00:06:45,920
# You are wearing a black tail.
# 115
# 00:06:45,920 --> 00:06:46,920
# It tickles.
# 116
# 00:06:54,920 --> 00:06:55,920
# What did you do?
# 117
# 00:06:56,920 --> 00:06:57,920
# It's embarrassing.
# 118
# 00:06:57,920 --> 00:06:59,920
# Is it?
# 119
# 00:07:00,920 --> 00:07:02,920
# I opened my eyes a little.
# 120
# 00:07:08,920 --> 00:07:10,920
# You found a cute person.
# 121
# 00:07:15,920 --> 00:07:17,920
# You found a cute person.
# 122
# 00:07:40,920 --> 00:07:42,920
# You usually have a big belly.
# 123
# 00:07:43,920 --> 00:07:44,920
# What do you like?
# 124
# 00:07:44,920 --> 00:07:46,920
# I like chocolate.
# 125
# 00:07:46,920 --> 00:07:47,920
# With your fingers?
# 126
# 00:07:47,920 --> 00:07:48,920
# Yes.
# 127
# 00:07:48,920 --> 00:07:50,920
# You are going to eat chocolate with your fingers.
# 128
# 00:07:50,920 --> 00:07:52,920
# Do you like chocolate?
# 129
# 00:07:52,920 --> 00:07:53,920
# Yes.
# 130
# 00:08:13,920 --> 00:08:14,920
# It tickles.
# 131
# 00:08:29,920 --> 00:08:31,920
# You are cute but erotic.
# 132
# 00:08:33,919 --> 00:08:35,919
# Let's take off your clothes.
# 133
# 00:08:36,919 --> 00:08:37,919
# It's difficult.
# 134
# 00:08:37,919 --> 00:08:38,919
# Why?
# 135
# 00:08:39,919 --> 00:08:41,919
# Let me see your face.
# 136
# 00:08:52,919 --> 00:08:54,919
# You have a big belly.
# 137
# 00:08:55,919 --> 00:08:56,919
# It tickles.
# 138
# 00:08:56,919 --> 00:08:57,919
# It's soft.
# 139
# 00:09:03,919 --> 00:09:05,919
# What do you like?
# 140
# 00:09:05,919 --> 00:09:06,919
# Do you like it?
# 141
# 00:09:07,919 --> 00:09:09,919
# How do you like it?
# 142
# 00:09:14,919 --> 00:09:16,919
# You have a soft belly.
# 143
# 00:09:16,919 --> 00:09:17,919
# It's beautiful.
# 144
# 00:09:22,919 --> 00:09:24,919
# Let me see your belly.
# 145
# 00:09:27,919 --> 00:09:29,919
# Please raise your head.
# 146
# 00:09:35,919 --> 00:09:36,919
# It's beautiful.
# 147
# 00:09:37,919 --> 00:09:39,919
# Please stand up.
# 148
# 00:09:43,919 --> 00:09:45,919
# It's beautiful.
# 149
# 00:09:46,919 --> 00:09:48,919
# You have a good style.
# 150
# 00:09:49,919 --> 00:09:50,919
# Are you embarrassed?
# 151
# 00:09:51,919 --> 00:09:53,919
# Let me see your butt.
# 152
# 00:09:54,919 --> 00:09:55,919
# Don't do that.
# 153
# 00:09:55,919 --> 00:09:56,919
# Don't do that.
# 154
# 00:10:06,919 --> 00:10:08,919
# You have a soft butt.
# 155
# 00:10:22,919 --> 00:10:24,919
# I don't want to touch your soft butt.
# 156
# 00:10:35,919 --> 00:10:36,919
# It tickles.
# 157
# 00:11:06,919 --> 00:11:07,919
# Do you like it?
# 158
# 00:11:07,919 --> 00:11:08,919
# Yes.
# 159
# 00:11:08,919 --> 00:11:09,919
# It's beautiful.
# 160
# 00:11:13,919 --> 00:11:14,919
# It tickles.
# 161
# 00:11:25,919 --> 00:11:26,919
# It tickles, right?
# 162
# 00:11:26,919 --> 00:11:27,919
# Yes.
# 163
# 00:11:35,919 --> 00:11:36,919
# It tickles, right?
# 164
# 00:11:36,919 --> 00:11:37,919
# Yes.
# 165
# 00:12:02,919 --> 00:12:03,919
# It tickles.
# 166
# 00:12:06,919 --> 00:12:08,919
# I didn't say I didn't like it.
# 167
# 00:12:18,919 --> 00:12:20,919
# I didn't say I didn't like it.
# 168
# 00:12:26,919 --> 00:12:28,919
# It's beautiful.
# 169
# 00:12:36,919 --> 00:12:37,919
# It tickles.
# 170
# 00:12:39,919 --> 00:12:40,919
# It tickles.
# 171
# 00:12:47,919 --> 00:12:48,919
# Don't you like it?
# 172
# 00:12:50,919 --> 00:12:52,919
# I didn't say I didn't like it.
# 173
# 00:12:52,919 --> 00:12:53,919
# It's very hard.
# 174
# 00:12:58,919 --> 00:12:59,919
# It's very hard.
# 175
# 00:12:59,919 --> 00:13:00,919
# Don't you like it?
# 176
# 00:13:05,919 --> 00:13:06,919
# It's very hard.
# 177
# 00:13:08,919 --> 00:13:09,919
# It's very hard.
# 178
# 00:13:14,919 --> 00:13:16,919
# How do you like it?
# 179
# 00:13:19,919 --> 00:13:20,919
# I want to touch it.
# 180
# 00:13:20,919 --> 00:13:21,919
# Do you want to touch it?
# 181
# 00:13:22,919 --> 00:13:23,919
# Where do you want to touch?
# 182
# 00:13:32,919 --> 00:13:34,919
# How do you like it?
# 183
# 00:13:36,919 --> 00:13:37,919
# I want to touch it.
# 184
# 00:13:37,919 --> 00:13:38,919
# Do you like it?
# 185
# 00:13:38,919 --> 00:13:39,919
# I want to touch it.
# 186
# 00:13:39,919 --> 00:13:40,919
# Do you like it?
# 187
# 00:14:06,919 --> 00:14:07,919
# How do you like it?
# 188
# 00:14:07,919 --> 00:14:08,919
# I want to touch it.
# 189
# 00:14:08,919 --> 00:14:09,919
# Do you want to touch it?
# 190
# 00:14:09,919 --> 00:14:10,919
# I want to touch it.
# 191
# 00:14:13,919 --> 00:14:16,919
# I'm going to leave it behind this time and give them a kiss.
# 192
# 00:14:19,919 --> 00:14:21,919
# I'm going to leave it behind this time and give them a kiss.
# 193
# 00:14:21,919 --> 00:14:22,919
# You'd rather like it or hate it.
# 194
# 00:14:22,919 --> 00:14:23,919
# I'd rather like it or hate it.
# 195
# 00:14:23,919 --> 00:14:24,919
# Very good.
# 196
# 00:14:24,919 --> 00:14:25,919
# Be careful.
# 197
# 00:14:25,919 --> 00:14:28,919
# I'm going to leave it behind this time and give them a kiss.
# 198
# 00:14:55,919 --> 00:14:57,919
# I'm going to leave it behind this time and give them a kiss.
# 199
# 00:15:25,919 --> 00:15:26,919
# I'm going to leave it behind this time and give them a kiss.
# 200
# 00:15:29,919 --> 00:15:30,919
# Do you want me to pat your chest?
# 201
# 00:15:30,919 --> 00:15:31,919
# Do you want me to pat your chest?
# 202
# 00:15:33,919 --> 00:15:34,919
# It's cute.
# 203
# 00:15:34,919 --> 00:15:35,919
# It's cute.
# 204
# 00:16:04,919 --> 00:16:05,919
# It looks like it's really soft.
# 205
# 00:16:13,919 --> 00:16:15,919
# It looks like it's really soft.
# 206
# 00:16:18,919 --> 00:16:20,919
# Are you satisfied?
# 207
# 00:16:23,919 --> 00:16:26,919
# What is this?
# 208
# 00:16:35,919 --> 00:16:40,919
# What's going on?
# 209
# 00:16:41,919 --> 00:16:44,919
# Why do you say you don't like it there?
# 210
# 00:16:52,919 --> 00:16:54,919
# Don't you want to see it?
# 211
# 00:16:57,919 --> 00:16:59,919
# Let's look over here.
# 212
# 00:16:59,919 --> 00:17:01,919
# This is amazing.
# 213
# 00:17:05,920 --> 00:17:07,920
# It's wet.
# 214
# 00:17:13,920 --> 00:17:15,920
# Look at this. It's amazing.
# 215
# 00:17:22,920 --> 00:17:25,920
# If this is the underwear, what's going on here?
# 216
# 00:17:26,920 --> 00:17:28,920
# Hey.
# 217
# 00:17:30,920 --> 00:17:32,920
# Let me see.
# 218
# 00:17:32,920 --> 00:17:34,920
# Let me see.
# 219
# 00:17:37,920 --> 00:17:39,920
# No, I'll hide it with my feet.
# 220
# 00:17:39,920 --> 00:17:41,920
# I don't want to.
# 221
# 00:17:47,920 --> 00:17:50,920
# Wait a minute. I'm pulling a lot of strings.
# 222
# 00:17:50,920 --> 00:17:52,920
# I don't want to.
# 223
# 00:17:53,920 --> 00:17:55,920
# Wait a minute.
# 224
# 00:17:55,920 --> 00:17:57,920
# Isn't this too wet?
# 225
# 00:18:01,920 --> 00:18:03,920
# It's amazing.
# 226
# 00:18:06,920 --> 00:18:08,920
# Spread it out firmly.
# 227
# 00:18:10,920 --> 00:18:11,920
# It's amazing.
# 228
# 00:18:11,920 --> 00:18:13,920
# My fingers are slippery.
# 229
# 00:18:23,920 --> 00:18:25,920
# It's amazing.
# 230
# 00:18:30,920 --> 00:18:32,920
# Why is it so wet?
# 231
# 00:18:32,920 --> 00:18:34,920
# It's amazing.
# 232
# 00:18:37,920 --> 00:18:39,920
# It's amazing.
# 233
# 00:18:52,920 --> 00:18:54,920
# It's amazing.
# 234
# 00:19:13,920 --> 00:19:15,920
# It's amazing.
# 235
# 00:19:16,920 --> 00:19:18,920
# It's amazing.
# 236
# 00:19:18,920 --> 00:19:20,920
# It's amazing.
# 237
# 00:19:21,920 --> 00:19:22,920
# I see.
# 238
# 00:19:22,920 --> 00:19:24,920
# Is it the entrance?
# 239
# 00:19:24,920 --> 00:19:26,920
# Or is it the back?
# 240
# 00:19:26,920 --> 00:19:28,920
# Isn't it outside?
# 241
# 00:19:41,920 --> 00:19:43,920
# It's very slippery.
# 242
# 00:19:48,920 --> 00:19:50,920
# It's amazing.
# 1
# 00:00:00,000 --> 00:00:13,000
# What should I do...
# 2
# 00:00:13,000 --> 00:00:15,000
# What are you doing?
# 3
# 00:00:15,000 --> 00:00:24,000
# Hu...
# 4
# 00:00:24,000 --> 00:00:31,000
# What should I do if you don't play with my finger?
# 5
# 00:00:31,000 --> 00:00:35,000
# It's a little slimy.
# 6
# 00:00:35,000 --> 00:00:38,000
# It's dirty.
# 7
# 00:00:38,000 --> 00:00:50,000
# I'll clean it up with my tongue.
# 8
# 00:00:50,000 --> 00:00:53,000
# Why?
# 9
# 00:00:53,000 --> 00:00:56,000
# I'll clean it up with my tongue.
# 10
# 00:01:23,000 --> 00:01:51,000
# I'll clean it up with my tongue.
# 11
# 00:01:51,000 --> 00:01:56,000
# Even if I lick it, it comes out.
# 12
# 00:02:21,000 --> 00:02:23,000
# It's dirty.
# 13
# 00:02:23,000 --> 00:02:25,000
# Is it dirty?
# 14
# 00:02:51,000 --> 00:03:09,000
# I want to lick it more.
# 15
# 00:03:09,000 --> 00:03:12,000
# No?
# 16
# 00:03:12,000 --> 00:03:14,000
# It doesn't move.
# 17
# 00:03:14,000 --> 00:03:21,000
# Then, instead...
# 18
# 00:03:21,000 --> 00:03:38,000
# Why don't you sleep here?
# 19
# 00:03:38,000 --> 00:03:45,000
# It doesn't feel good.
# 20
# 00:03:45,000 --> 00:04:13,000
# Do you want me to clean it up?
# 21
# 00:04:13,000 --> 00:04:21,000
# Please.
# 22
# 00:04:43,000 --> 00:04:53,000
# It doesn't feel good.
# 23
# 00:04:53,000 --> 00:05:18,000
# It's dirty.
# 24
# 00:05:18,000 --> 00:05:23,000
# Please lick it while cleaning it up.
# 25
# 00:05:23,000 --> 00:05:41,000
# It's so cute.
# 26
# 00:05:41,000 --> 00:05:51,000
# It's dirty.
# 27
# 00:05:51,000 --> 00:06:12,000
# It's dirty.
# 28
# 00:06:12,000 --> 00:06:39,000
# Please lick it more.
# 29
# 00:06:39,000 --> 00:06:50,000
# Can you lick it to some extent?
# 30
# 00:06:50,000 --> 00:07:13,000
# It's dirty.
# 31
# 00:07:14,000 --> 00:07:40,000
# It doesn't feel good.
# 32
# 00:07:40,000 --> 00:07:43,000
# Please lick it while cleaning it up.
# 33
# 00:08:10,000 --> 00:08:38,000
# It's dirty.
# 34
# 00:08:39,000 --> 00:09:07,000
# Please lick it while cleaning it up.
# 35
# 00:09:07,000 --> 00:09:29,000
# It doesn't feel good.
# 36
# 00:09:29,000 --> 00:09:58,000
# It doesn't feel good.
# 37
# 00:09:58,000 --> 00:10:06,000
# It doesn't feel good.
# 38
# 00:10:06,000 --> 00:10:08,000
# Did you do it yourself and get wet again?
# 39
# 00:10:08,000 --> 00:10:23,000
# Did you do it yourself and get wet again?
# 40
# 00:10:23,000 --> 00:10:33,000
# Do you want me to put it in your eyes?
# 41
# 00:10:33,000 --> 00:10:58,000
# Do you want me to put it in your eyes?
# 42
# 00:10:58,000 --> 00:11:13,000
# It doesn't feel good.
# 43
# 00:11:13,000 --> 00:11:41,000
# It doesn't feel good.
# 44
# 00:11:41,000 --> 00:11:54,000
# It doesn't feel good.
# 45
# 00:11:54,000 --> 00:12:06,000
# It doesn't feel good.
# 46
# 00:12:06,000 --> 00:12:13,000
# It doesn't feel good.
# 47
# 00:12:13,000 --> 00:12:15,000
# Did you do it yourself and get wet again?
# 48
# 00:12:15,000 --> 00:12:32,000
# Did you do it yourself and get wet again?
# 49
# 00:12:32,000 --> 00:13:01,000
# It doesn't feel good.
# 50
# 00:13:01,000 --> 00:13:11,000
# It doesn't feel good.
# 51
# 00:13:11,000 --> 00:13:40,000
# It doesn't feel good.
# 52
# 00:13:40,000 --> 00:13:55,000
# It doesn't feel good.
# 53
# 00:13:55,000 --> 00:14:15,000
# It doesn't feel good.
# 54
# 00:14:15,000 --> 00:14:35,000
# It doesn't feel good.
# 55
# 00:14:35,000 --> 00:14:55,000
# It doesn't feel good.
# 56
# 00:14:55,000 --> 00:15:05,000
# It doesn't feel good.
# 57
# 00:15:05,000 --> 00:15:25,000
# It doesn't feel good.
# 58
# 00:15:25,000 --> 00:15:53,000
# It doesn't feel good.
# 59
# 00:15:53,000 --> 00:16:21,000
# It doesn't feel good.
# 60
# 00:16:21,000 --> 00:16:30,000
# Lean on me.
# 61
# 00:16:30,000 --> 00:16:32,000
# It's amazing.
# 62
# 00:16:32,000 --> 00:16:38,000
# It's very tight.
# 63
# 00:16:38,000 --> 00:16:48,000
# Does it feel good?
# 64
# 00:16:48,000 --> 00:16:55,000
# It's very tight.
# 65
# 00:16:55,000 --> 00:17:17,000
# Does it feel good?
# 66
# 00:17:17,000 --> 00:17:46,000
# It doesn't feel good.
# 67
# 00:17:46,000 --> 00:17:48,000
# It doesn't feel good.
# 68
# 00:17:48,000 --> 00:18:17,000
# It's very tight.
# 69
# 00:18:17,000 --> 00:18:19,000
# It doesn't feel good.
# 70
# 00:18:47,000 --> 00:18:52,000
# It doesn't feel good.
# 71
# 00:18:52,000 --> 00:19:02,000
# It doesn't feel good.
# 72
# 00:19:02,000 --> 00:19:12,000
# It doesn't feel good.
# 73
# 00:19:12,000 --> 00:19:22,000
# It doesn't feel good.
# 74
# 00:19:22,000 --> 00:19:32,000
# It doesn't feel good.
# 75
# 00:19:32,000 --> 00:19:34,000
# It doesn't feel good.
# 76
# 00:19:34,000 --> 00:19:37,000
# It doesn't feel good.
# 77
# 00:19:37,000 --> 00:20:00,000
# It doesn't feel good.
# 1
# 00:00:00,000 --> 00:00:04,600
# Oh my gosh.
# 2
# 00:00:04,600 --> 00:00:09,340
# Oh my gosh.
# 3
# 00:00:09,340 --> 00:00:13,640
# So much trembling.
# 4
# 00:00:13,640 --> 00:00:16,959
# I love you.
# 5
# 00:00:16,959 --> 00:00:21,080
# I love you.
# 6
# 00:00:21,080 --> 00:00:24,420
# I love you.
# 7
# 00:00:24,420 --> 00:00:28,059
# I love you.
# 8
# 00:02:58,259 --> 00:03:00,039
# I love you.
# 9
# 00:03:19,220 --> 00:03:22,679
# Let me scratch your back.
# 10
# 00:03:29,059 --> 00:03:33,059
# I'm so nervous that I can't eat.
# 11
# 00:03:51,059 --> 00:03:53,059
# Stretch your legs.
# 12
# 00:03:58,059 --> 00:04:00,059
# I'm so nervous that I can't eat.
# 13
# 00:04:17,059 --> 00:04:19,059
# I'm so nervous that I can't eat.
# 14
# 00:04:28,059 --> 00:04:30,059
# I'm so nervous that I can't eat.
# 15
# 00:04:58,059 --> 00:05:00,059
# I'm so nervous that I can't eat.
# 16
# 00:05:28,059 --> 00:05:30,059
# I'm so nervous that I can't eat.
# 17
# 00:05:58,059 --> 00:06:00,059
# I'm so nervous that I can't eat.
# 18
# 00:06:08,059 --> 00:06:10,059
# Can you put your hand on top of my head?
# 19
# 00:06:10,059 --> 00:06:12,059
# Can you put your hand on top of my head?
# 20
# 00:06:28,059 --> 00:06:30,059
# I'm so nervous that I can't eat.
# 21
# 00:06:58,059 --> 00:07:00,059
# I'm so nervous that I can't eat.
# 22
# 00:07:28,059 --> 00:07:30,059
# I'm so nervous that I can't eat.
# 23
# 00:07:58,059 --> 00:08:00,059
# I'm so nervous that I can't eat.
# 24
# 00:08:28,059 --> 00:08:30,059
# I'm so nervous that I can't eat.
# 25
# 00:08:58,059 --> 00:09:00,059
# I'm so nervous that I can't eat.
# 26
# 00:09:28,059 --> 00:09:30,059
# I'm so nervous that I can't eat.
# 27
# 00:09:58,059 --> 00:10:00,059
# I'm so nervous that I can't eat.
# 28
# 00:10:28,059 --> 00:10:30,059
# I'm so nervous that I can't eat.
# 29
# 00:10:58,059 --> 00:11:00,059
# I'm so nervous that I can't eat.
# 30
# 00:11:16,059 --> 00:11:18,059
# I'm so nervous that I can't eat.
# 31
# 00:11:28,059 --> 00:11:30,059
# I'm so nervous that I can't eat.
# 32
# 00:11:44,059 --> 00:11:46,059
# I'm so nervous that I can't eat.
# 33
# 00:11:50,059 --> 00:11:52,059
# Can I go inside?
# 34
# 00:11:52,059 --> 00:11:54,059
# Can I go inside?
# 35
# 00:11:54,059 --> 00:11:56,059
# Can I go inside?
# 36
# 00:11:58,059 --> 00:12:00,059
# Can I go inside?
# 37
# 00:12:00,059 --> 00:12:02,059
# Can I go inside?
# 38
# 00:12:02,059 --> 00:12:04,059
# Can I go inside?
# 39
# 00:12:04,059 --> 00:12:06,059
# Can I go inside?
# 40
# 00:12:06,059 --> 00:12:08,059
# Can I go inside?
# 41
# 00:12:26,059 --> 00:12:28,059
# Can I go inside?
# 42
# 00:12:36,059 --> 00:12:38,059
# Can I go inside?
# 43
# 00:12:52,059 --> 00:12:54,059
# Can I go inside?
# 44
# 00:13:06,059 --> 00:13:08,059
# Can I go inside?
# 45
# 00:13:24,059 --> 00:13:26,059
# I'll suck it all out.
# 46
# 00:13:26,059 --> 00:13:28,059
# I'll suck it all out.
# 47
# 00:13:52,059 --> 00:13:54,059
# I'm so cute that I'm scared.
# 48
# 00:13:56,059 --> 00:13:58,059
# What does it taste like?
# 49
# 00:13:58,059 --> 00:14:00,059
# What does it taste like?
# 50
# 00:14:00,059 --> 00:14:02,059
# bitter?
# 51
# 00:14:02,059 --> 00:14:04,059
# bitter?
# 52
# 00:14:26,059 --> 00:14:28,059
# I've had enough.
# 53
# 00:14:28,059 --> 00:14:30,059
# I've had enough.
# 54
# 00:14:30,059 --> 00:14:32,059
# I've had enough.
# 55
# 00:14:32,059 --> 00:14:34,059
# I've had enough.
# 56
# 00:14:36,059 --> 00:14:38,059
# It looks done.
# 57
# 00:14:38,059 --> 00:14:40,059
# It looks done.
# 58
# 00:14:42,059 --> 00:14:44,059
# The end
# 1
# 00:00:00,000 --> 00:00:22,400
# 我。
# 2
# 00:00:22,400 --> 00:00:39,759
# 他是个马屁精。
# 3
# 00:00:39,759 --> 00:00:47,919
# 现在让我们问他几个问题。
# 4
# 00:00:47,919 --> 00:00:54,919
# 首先，让我们问他对自己的新发色有什么感觉。
# 5
# 00:00:54,919 --> 00:01:01,919
# 我不确定他对自己的新发色有什么感觉，所以我要问他几个问题。
# 6
# 00:01:01,919 --> 00:01:06,919
# 首先，让我们问他对自己的新发色有什么感觉。
# 7
# 00:01:06,919 --> 00:01:07,919
# 你好。
# 8
# 00:01:07,919 --> 00:01:08,919
# 什么？
# 9
# 00:01:08,919 --> 00:01:09,919
# 你好。
# 10
# 00:01:09,919 --> 00:01:10,919
# 你好。
# 11
# 00:01:10,919 --> 00:01:18,919
# 你总是看起来很漂亮。
# 12
# 00:01:18,919 --> 00:01:20,919
# 谢谢。
# 13
# 00:01:20,919 --> 00:01:22,919
# 人们经常这么说吗？
# 14
# 00:01:22,919 --> 00:01:24,919
# 不，他们不这么说。
# 15
# 00:01:24,919 --> 00:01:25,919
# 他们不这么说？
# 16
# 00:01:25,919 --> 00:01:26,919
# 不。
# 17
# 00:01:26,919 --> 00:01:33,919
# 你今天来这里是为了什么？
# 18
# 00:01:33,919 --> 00:01:36,919
# 我来这里玩。
# 19
# 00:01:36,919 --> 00:01:37,919
# 玩？
# 20
# 00:01:37,919 --> 00:01:38,919
# 是的。
# 21
# 00:01:39,919 --> 00:01:44,919
# 是什么样的玩？
# 22
# 00:01:44,919 --> 00:01:48,919
# 好玩的玩。
# 23
# 00:01:48,919 --> 00:01:51,919
# 你看起来很开心。
# 24
# 00:01:51,919 --> 00:01:53,919
# 我看起来很开心。
# 25
# 00:01:53,919 --> 00:01:58,919
# 那里有什么样的人？
# 26
# 00:01:58,919 --> 00:02:06,919
# 高个子的人。
# 27
# 00:02:06,919 --> 00:02:09,919
# 戴口罩的人。
# 28
# 00:02:09,919 --> 00:02:11,919
# 他们可疑吗？
# 29
# 00:02:11,919 --> 00:02:12,919
# 可疑。
# 30
# 00:02:12,919 --> 00:02:13,919
# 可疑？
# 31
# 00:02:13,919 --> 00:02:14,919
# 是的。
# 32
# 00:02:14,919 --> 00:02:19,919
# 那么，我要问你一个有趣的问题。
# 33
# 00:02:19,919 --> 00:02:20,919
# 好的。
# 34
# 00:02:20,919 --> 00:02:21,919
# 你准备好了吗？
# 35
# 00:02:21,919 --> 00:02:22,919
# 好的。
# 36
# 00:02:22,919 --> 00:02:25,919
# 请开始。
# 37
# 00:02:25,919 --> 00:02:26,919
# 你好。
# 38
# 00:02:26,919 --> 00:02:27,919
# 你好。
# 39
# 00:02:27,919 --> 00:02:28,919
# 你是个可疑的人。
# 40
# 00:02:28,919 --> 00:02:29,919
# 是的，我是。
# 41
# 00:02:29,919 --> 00:02:31,919
# 你太可爱了。
# 42
# 00:02:31,919 --> 00:02:33,919
# 谢谢。
# 43
# 00:02:33,919 --> 00:02:35,919
# 你多大了？
# 44
# 00:02:35,919 --> 00:02:36,919
# 我22岁。
# 45
# 00:02:36,919 --> 00:02:37,919
# 22岁。
# 46
# 00:02:37,919 --> 00:02:38,919
# 我明白了。
# 47
# 00:02:38,919 --> 00:02:41,919
# 那是什么意思？
# 48
# 00:02:41,919 --> 00:02:42,919
# 你是社交工作者吗？
# 49
# 00:02:42,919 --> 00:02:44,919
# 我是大四的大学生。
# 50
# 00:02:44,919 --> 00:02:45,919
# 大四的大学生？
# 51
# 00:02:45,919 --> 00:02:46,919
# 是的。
# 52
# 00:02:46,919 --> 00:02:54,919
# 我不知道你在大四的时候玩得这么开心。
# 53
# 00:02:54,919 --> 00:02:57,919
# 你有点炫耀，不是吗？
# 54
# 00:02:57,919 --> 00:02:58,919
# 有点。
# 55
# 00:02:58,919 --> 00:02:59,919
# 只有一点？
# 56
# 00:02:59,919 --> 00:03:00,919
# 是的。
# 57
# 00:03:01,919 --> 00:03:02,919
# 我明白了。
# 58
# 00:03:02,919 --> 00:03:10,919
# 如果你是这样一个漂亮的女孩，即使你不这样玩，很多男孩也会来找你。
# 59
# 00:03:10,919 --> 00:03:12,919
# 不，他们不会。
# 60
# 00:03:12,919 --> 00:03:13,919
# 什么？
# 61
# 00:03:13,919 --> 00:03:16,919
# 我觉得你周围没有人注意你。
# 62
# 00:03:16,919 --> 00:03:17,919
# 我明白了。
# 63
# 00:03:17,919 --> 00:03:19,919
# 不。
# 64
# 00:03:19,919 --> 00:03:25,919
# 那么，今天我要和一个没有注意力的男孩聊天。
# 65
# 00:03:25,919 --> 00:03:27,919
# 好的。
# 66
# 00:03:28,919 --> 00:03:30,919
# 你的皮肤真白真漂亮。
# 67
# 00:03:30,919 --> 00:03:32,919
# 脏了。
# 68
# 00:03:32,919 --> 00:03:33,919
# 为什么？
# 69
# 00:03:33,919 --> 00:03:35,919
# 为什么你不那么自信？
# 70
# 00:03:35,919 --> 00:03:37,919
# 我不自信。
# 71
# 00:03:39,919 --> 00:03:41,919
# 你太可爱了。
# 72
# 00:03:41,919 --> 00:03:42,919
# 是的。
# 73
# 00:03:47,919 --> 00:03:50,919
# 你的嘴唇小而可爱。
# 74
# 00:03:57,919 --> 00:03:58,919
# 是的。
# 75
# 00:04:57,920 --> 00:04:59,920
# 你的嘴唇很柔软。
# 76
# 00:05:02,920 --> 00:05:04,920
# 你有多少男孩？
# 77
# 00:05:04,920 --> 00:05:05,920
# 不多。
# 78
# 00:05:05,920 --> 00:05:06,920
# 什么？
# 79
# 00:05:06,920 --> 00:05:07,920
# 不多。
# 80
# 00:05:07,920 --> 00:05:08,920
# 不多？
# 81
# 00:05:08,920 --> 00:05:09,920
# 是的。
# 82
# 00:05:09,920 --> 00:05:10,920
# 大约五个？
# 83
# 00:05:10,920 --> 00:05:12,920
# 我不知道。
# 84
# 00:05:12,920 --> 00:05:13,920
# 你不知道？
# 85
# 00:05:14,920 --> 00:05:16,920
# 我想知道你有多少男孩。
# 86
# 00:05:17,920 --> 00:05:20,920
# 那么，今天我要和一个没有注意力的男孩聊天。
# 87
# 00:05:21,920 --> 00:05:22,920
# 我明白了。
# 88
# 00:05:24,920 --> 00:05:26,920
# 我很兴奋。
# 89
# 00:05:28,920 --> 00:05:30,920
# 你有好的风格。
# 90
# 00:05:31,920 --> 00:05:33,920
# 你身材很好。
# 91
# 00:05:35,920 --> 00:05:37,920
# 你有很多胸部。
# 92
# 00:05:43,920 --> 00:05:45,920
# 你喜欢什么样的风格？
# 93
# 00:05:47,920 --> 00:05:48,920
# 什么？
# 94
# 00:05:49,920 --> 00:05:51,920
# 你胸口有什么感觉吗？
# 95
# 00:05:52,920 --> 00:05:53,920
# 我喜欢温柔的风格。
# 96
# 00:05:53,920 --> 00:05:55,920
# 温柔的风格？
# 97
# 00:05:55,920 --> 00:05:56,920
# 别担心。
# 98
# 00:05:56,920 --> 00:05:58,920
# 我有温柔的风格。
# 99
# 00:06:01,920 --> 00:06:03,920
# 你还有其他敏感的地方吗？
# 100
# 00:06:04,920 --> 00:06:06,920
# 像耳朵或脖子？
# 101
# 00:06:07,920 --> 00:06:08,920
# 痒。
# 102
# 00:06:08,920 --> 00:06:09,920
# 真的吗？
# 103
# 00:06:09,920 --> 00:06:10,920
# 是的。
# 104
# 00:06:10,920 --> 00:06:11,920
# 让我看看你的脖子。
# 105
# 00:06:19,920 --> 00:06:20,920
# 痒。
# 106
# 00:06:20,920 --> 00:06:22,920
# 痒吗？
# 107
# 00:06:22,920 --> 00:06:24,920
# 痒吗？
# 108
# 00:06:24,920 --> 00:06:25,920
# 痒。
# 109
# 00:06:29,920 --> 00:06:31,920
# 你太可爱了。
# 110
# 00:06:33,920 --> 00:06:34,920
# 是的。
# 111
# 00:06:47,920 --> 00:06:50,920
# 你的嘴唇又软又滑。
# 112
# 00:06:56,920 --> 00:06:57,920
# 你做了什么？
# 113
# 00:06:58,920 --> 00:06:59,920
# 很尴尬。
# 114
# 00:06:59,920 --> 00:07:01,920
# 是吗？
# 115
# 00:07:00,920 --> 00:07:02,920
# 我睁开了一点眼睛。
# 116
# 00:07:08,920 --> 00:07:10,920
# 你找到了一个可爱的人。
# 117
# 00:07:15,920 --> 00:07:17,920
# 你找到了一个可爱的人。
# 118
# 00:07:40,920 --> 00:07:42,920
# 你通常有一个大肚子。
# 119
# 00:07:43,920 --> 00:07:44,920
# 你喜欢什么？
# 120
# 00:07:44,920 --> 00:07:46,920
# 我喜欢巧克力。
# 121
# 00:07:46,920 --> 00:07:47,920
# 用手指吗？
# 122
# 00:07:47,920 --> 00:07:48,920
# 是的。
# 123
# 00:07:48,920 --> 00:07:50,920
# 你要用手指吃巧克力。
# 124
# 00:07:50,920 --> 00:07:52,920
# 你喜欢巧克力吗？
# 125
# 00:07:52,920 --> 00:07:53,920
# 是的。
# 126
# 00:08:13,920 --> 00:08:14,920
# 痒。
# 127
# 00:08:29,920 --> 00:08:31,920
# 你很可爱，但又很色情。
# 128
# 00:08:33,919 --> 00:08:35,919
# 让我们脱掉你的衣服。
# 129
# 00:08:36,919 --> 00:08:37,919
# 很困难。
# 130
# 00:08:37,919 --> 00:08:38,919
# 为什么？
# 131
# 00:08:39,919 --> 00:08:41,919
# 让我看看你的脸。
# 132
# 00:08:52,919 --> 00:08:54,919
# 你有一个大肚子。
# 133
# 00:08:55,919 --> 00:08:56,919
# 痒。
# 134
# 00:08:56,919 --> 00:08:57,919
# 软软的。
# 135
# 00:09:03,919 --> 00:09:05,919
# 你喜欢什么？
# 136
# 00:09:05,919 --> 00:09:06,919
# 你喜欢吗？
# 137
# 00:09:07,919 --> 00:09:09,919
# 你喜欢什么样的？
# 138
# 00:09:14,919 --> 00:09:16,919
# 你有一个软软的肚子。
# 139
# 00:09:16,919 --> 00:09:17,919
# 很漂亮。
# 140
# 00:09:22,919 --> 00:09:24,919
# 让我看看你的肚子。
# 141
# 00:09:27,919 --> 00:09:29,919
# 请抬起头。
# 142
# 00:09:35,919 --> 00:09:36,919
# 很漂亮。
# 143
# 00:09:37,919 --> 00:09:39,919
# 请站起来。
# 144
# 00:09:43,919 --> 00:09:45,919
# 很漂亮。
# 145
# 00:09:46,919 --> 00:09:48,919
# 你有一个好身材。
# 146
# 00:09:49,919 --> 00:09:50,919
# 你尴尬吗？
# 147
# 00:09:51,919 --> 00:09:53,919
# 让我看看你的屁股。
# 148
# 00:09:54,919 --> 00:09:55,919
# 别这样。
# 149
# 00:09:55,919 --> 00:09:56,919
# 别这样。
# 150
# 00:10:06,919 --> 00:10:08,919
# 你有一个软软的屁股。
# 151
# 00:10:22,919 --> 00:10:24,919
# 我不想碰你软软的屁股。
# 152
# 00:10:35,919 --> 00:10:36,919
# 痒。
# 153
# 00:11:06,919 --> 00:11:07,919
# 你喜欢吗？
# 154
# 00:11:07,919 --> 00:11:08,919
# 是的。
# 155
# 00:11:08,919 --> 00:11:09,919
# 很漂亮。
# 156
# 00:11:13,919 --> 00:11:14,919
# 痒。
# 157
# 00:11:25,919 --> 00:11:26,919
# 痒，对吧？
# 158
# 00:11:26,919 --> 00:11:27,919
# 是的。
# 159
# 00:11:35,919 --> 00:11:36,919
# 痒，对吧？
# 160
# 00:11:36,919 --> 00:11:37,919
# 是的。
# 161
# 00:12:02,919 --> 00:12:03,919
# 痒。
# 162
# 00:12:06,919 --> 00:12:08,919
# 我没说我不喜欢。
# 163
# 00:12:18,919 --> 00:12:20,919
# 我没说我不喜欢。
# 164
# 00:12:26,919 --> 00:12:28,919
# 很漂亮。
# 165
# 00:12:36,919 --> 00:12:37,919
# 痒。
# 166
# 00:12:39,919 --> 00:12:40,919
# 痒。
# 167
# 00:12:47,919 --> 00:12:48,919
# 你不喜欢吗？
# 168
# 00:12:50,919 --> 00:12:52,919
# 我没说我不喜欢。
# 169
# 00:12:52,919 --> 00:12:53,919
# 很硬。
# 170
# 00:12:58,919 --> 00:12:59,919
# 很硬。
# 171
# 00:12:59,919 --> 00:13:00,919
# 你不喜欢吗？
# 172
# 00:13:05,919 --> 00:13:06,919
# 很硬。
# 173
# 00:13:08,919 --> 00:13:09,919
# 很硬。
# 174
# 00:13:14,919 --> 00:13:16,919
# 你喜欢什么样的？
# 175
# 00:13:19,919 --> 00:13:20,919
# 我想摸摸它。
# 176
# 00:13:20,919 --> 00:13:21,919
# 你想摸摸它吗？
# 177
# 00:13:22,919 --> 00:13:23,919
# 你想摸摸它吗？
# 178
# 00:13:23,919 --> 00:13:24,919
# 你想摸摸它吗？
# 179
# 00:13:24,919 --> 00:13:25,919
# 你想摸摸它吗？
# 180
# 00:13:25,919 --> 00:13:26,919
# 你想摸摸它吗？
# 181
# 00:14:06,919 --> 00:14:07,919
# 你喜欢什么样的？
# 182
# 00:14:07,919 --> 00:14:08,919
# 我想摸摸它。
# 183
# 00:14:08,919 --> 00:14:09,919
# 你喜欢吗？
# 184
# 00:14:09,919 --> 00:14:10,919
# 我想摸摸它。
# 185
# 00:14:10,919 --> 00:14:11,919
# 你喜欢吗？
# 186
# 00:14:11,919 --> 00:14:12,919
# 我想摸摸它。
# 187
# 00:14:12,919 --> 00:14:13,919
# 你喜欢吗？
# 188
# 00:14:13,919 --> 00:14:14,919
# 我想摸摸它。
# 189
# 00:14:14,919 --> 00:14:15,919
# 你喜欢吗？
# 190
# 00:14:15,919 --> 00:14:16,919
# 我想摸摸它。
# 191
# 00:14:19,919 --> 00:14:21,919
# 这次我要留下来，给他们一个吻。
# 192
# 00:14:21,919 --> 00:14:22,919
# 你更喜欢喜欢还是讨厌。
# 193
# 00:14:22,919 --> 00:14:23,919
# 你更喜欢喜欢还是讨厌。
# 194
# 00:14:23,919 --> 00:14:24,919
# 非常好。
# 195
# 00:14:24,919 --> 00:14:25,919
# 小心。
# 196
# 00:14:25,919 --> 00:14:28,919
# 这次我要留下来，给他们一个吻。
# 197
# 00:14:55,919 --> 00:14:57,919
# 这次我要留下来，给他们一个吻。
# 198
# 00:15:25,919 --> 00:15:26,919
# 这次我要留下来，给他们一个吻。
# 199
# 00:15:29,919 --> 00:15:30,919
# 你想让我拍拍你的胸部吗？
# 200
# 00:15:30,919 --> 00:15:31,919
# 你想让我拍拍你的胸部吗？
# 201
# 00:15:33,919 --> 00:15:34,919
# 太可爱了。
# 202
# 00:15:34,919 --> 00:15:35,919
# 太可爱了。
# 203
# 00:16:04,919 --> 00:16:05,919
# 看起来真的很软。
# 204
# 00:16:13,919 --> 00:16:15,919
# 看起来真的很软。
# 205
# 00:16:18,919 --> 00:16:20,919
# 你满意吗？
# 206
# 00:16:23,919 --> 00:16:26,919
# 这是什么？
# 207
# 00:16:35,919 --> 00:16:40,919
# 发生了什么？
# 208
# 00:16:41,919 --> 00:16:44,919
# 为什么你说你不喜欢那里？
# 209
# 00:16:52,919 --> 00:16:54,919
# 你不想看吗？
# 210
# 00:16:57,919 --> 00:16:59,919
# 让我们看看这边。
# 211
# 00:16:59,919 --> 00:17:01,919
# 这真是太棒了。
# 212
# 00:17:05,920 --> 00:17:07,920
# 很湿。
# 213
# 00:17:13,920 --> 00:17:15,920
# 看这个，太棒了。
# 214
# 00:17:22,920 --> 00:17:25,920
# 如果这是内衣，那这是什么？
# 215
# 00:17:26,920 --> 00:17:28,920
# 嘿。
# 216
# 00:17:30,920 --> 00:17:32,920
# 让我看看。
# 217
# 00:17:32,920 --> 00:17:34,920
# 让我看看。
# 218
# 00:17:37,920 --> 00:17:39,920
# 不，我要用脚把它藏起来。
# 219
# 00:17:39,920 --> 00:17:41,920
# 我不想。
# 220
# 00:17:47,920 --> 00:17:50,920
# 等一下。我拉了很多线。
# 221
# 00:17:50,920 --> 00:17:52,920
# 我不想。
# 222
# 00:17:53,920 --> 00:17:55,920
# 等一下。
# 223
# 00:17:55,920 --> 00:17:57,920
# 这是不是太湿了？
# 224
# 00:18:01,920 --> 00:18:03,920
# 太棒了。
# 225
# 00:18:06,920 --> 00:18:08,920
# 真是太棒了。
# 226
# 00:18:10,920 --> 00:18:11,920
# 展开得牢牢的。
# 227
# 00:18:11,920 --> 00:18:13,920
# 我的手指滑溜溜的。
# 228
# 00:18:23,920 --> 00:18:25,920
# 真是太棒了。
# 229
# 00:18:30,920 --> 00:18:32,920
# 为什么这么湿？
# 230
# 00:18:32,920 --> 00:18:34,920
# 真是太棒了。
# 231
# 00:18:37,920 --> 00:18:39,920
# 真是太棒了。
# 232
# 00:18:52,920 --> 00:18:54,920
# 真是太棒了。
# 233
# 00:19:13,920 --> 00:19:15,920
# 真是太棒了。
# 234
# 00:19:16,920 --> 00:19:18,920
# 真是太棒了。
# 235
# 00:19:18,920 --> 00:19:20,920
# 真是太棒了。
# 236
# 00:19:21,920 --> 00:19:22,920
# 我明白了。
# 237
# 00:19:22,920 --> 00:19:24,920
# 是入口吗？
# 238
# 00:19:24,920 --> 00:19:26,920
# 还是后面？
# 239
# 00:19:26,920 --> 00:19:28,920
# 是外面吗？
# 240
# 00:19:41,920 --> 00:19:43,920
# 非常滑。
# 241
# 00:19:48,920 --> 00:19:50,920
# 看这个，太棒了。
# 242
# 00:19:55,920 --> 00:19:57,920
# 等一下。我拉了很多线。
# 243
# 00:19:57,920 --> 00:19:59,920
# 我不想。
# 244
# 00:20:00,920 --> 00:20:02,920
# 等一下。
# 245
# 00:20:02,920 --> 00:20:04,920
# 这是不是太湿了？
# 246
# 00:20:08,920 --> 00:20:10,920
# 太棒了。
# 247
# 00:20:13,920 --> 00:20:15,920
# 这是什么？
# 248
# 00:20:20,920 --> 00:20:22,920
# 这是什么？
# 249
# 00:20:22,920 --> 00:20:24,920
# 这是什么？
# 250
# 00:20:24,920 --> 00:20:26,920
# 这是什么？
# 251
# 00:20:26,920 --> 00:20:28,920
# 这是什么？
# 252
# 00:20:28,920 --> 00:20:30,920
# 这是什么？
# 253
# 00:20:30,920 --> 00:20:32,920
# 这是什么？
# 254
# 00:20:32,920 --> 00:20:34,920
# 这是什么？
# 255
# 00:20:34,920 --> 00:20:36,920
# 这是什么？
# 256
# 00:20:36,920 --> 00:20:38,920
# 这是什么？
# 257
# 00:20:38,920 --> 00:20:40,920
# 这是什么？
# 258
# 00:20:40,920 --> 00:20:42,920
# 这是什么？
# 259
# 00:20:42,920 --> 00:20:44,920
# 这是什么？
# 260
# 00:20:44,920 --> 00:20:46,920
# 这是什么？
# 261
# 00:20:46,920 --> 00:20:48,920
# 这是什么？
# 262
# 00:20:48,920 --> 00:20:50,920
# 这是什么？
# 263
# 00:20:50,920 --> 00:20:52,920
# 这是什么？
# 264
# 00:20:52,920 --> 00:20:54,920
# 这是什么？
# 265
# 00:20:54,920 --> 00:20:56,920
# 这是什么？
# 266
# 00:20:56,920 --> 00:20:58,920
# 这是什么？
# 267
# 00:20:58,920 --> 00:21:00,920
# 这是什么？
# 268
# 00:21:00,920 --> 00:21:02,920
# 这是什么？
# 269
# 00:21:02,920 --> 00:21:04,920
# 这是什么？
# 270
# 00:21:04,920 --> 00:21:06,920
# 这是什么？
# 271
# 00:21:06,920 --> 00:21:08,920
# 这是什么？
# 272
# 00:21:08,920 --> 00:21:10,920
# 这是什么？
# 273
# 00:21:10,920 --> 00:21:12,920
# 这是什么？
# 274
# 00:21:12,920 --> 00:21:14,920
# 这是什么？
# 275
# 00:21:14,920 --> 00:21:16,920
# 这是什么？
# 276
# 00:21:16,920 --> 00:21:18,920
# 这是什么？
# 277
# 00:21:18,920 --> 00:21:20,920
# 这是什么？
# 278
# 00:21:20,920 --> 00:21:22,920
# 这是什么？
# 279
# 00:21:22,920 --> 00:21:24,920
# 这是什么？
# 280
# 00:21:24,920 --> 00:21:26,920
# 这是什么？
# 281
# 00:21:26,920 --> 00:21:28,920
# 这是什么？
# 282
# 00:21:28,920 --> 00:21:30,920
# 这是什么？
# 283
# 00:21:30,920 --> 00:21:32,920
# 这是什么？
# 284
# 00:21:32,920 --> 00:21:34,920
# 这是什么？
# 285
# 00:21:34,920 --> 00:21:36,920
# 这是什么？
# 286
# 00:21:36,920 --> 00:21:38,920
# 这是什么？
# 287
# 00:21:38,920 --> 00:21:40,920
# 这是什么？
# 288
# 00:21:40,920 --> 00:21:42,920
# 这是什么？
# 289
# 00:21:42,920 --> 00:21:44,920
# 这是什么？
# 290
# 00:21:44,920 --> 00:21:46,920
# 这是什么？
# 291
# 00:21:46,920 --> 00:21:48,920
# 这是什么？
# 292
# 00:21:48,920 --> 00:21:50,920
# 这是什么？
# 293
# 00:21:50,920 --> 00:21:52,920
# 这是什么？
# 294
# 00:21:52,920 --> 00:21:54,920
# 这是什么？
# 295
# 00:21:54,920 --> 00:21:56,920
# 这是什么？
# 296
# 00:21:56,920 --> 00:21:58,920
# 这是什么？
# 297
# 00:21:58,920 --> 00:22:00,920
# 这是什么？
# 298
# 00:22:00,920 --> 00:22:02,920
# 这是什么？
# 299
# 00:22:02,920 --> 00:22:04,920
# 这是什么？
# 300
# 00:22:04,920 --> 00:22:06,920
# 这是什么？
# 301
# 00:22:06,920 --> 00:22:08,920
# 这是什么？
# 302
# 00:22:08,920 --> 00:22:10,920
# 这是什么？
# 303
# 00:22:10,920 --> 00:22:12,920
# 这是什么？
# 304
# 00:22:12,920 --> 00:22:14,920
# 这是什么？
# 305
# 00:22:14,920 --> 00:22:16,920
# 这是什么？
# 306
# 00:22:16,920 --> 00:22:18,920
# 这是什么？
# 307
# 00:22:18,920 --> 00:22:20,920
# 这是什么？
# 308
# 00:22:20,920 --> 00:22:22,920
# 这是什么？
# 309
# 00:22:22,920 --> 00:22:24,920
# 这是什么？
# 310
# 00:22:24,920 --> 00:22:26,920
# 这是什么？
# 311
# 00:22:26,920 --> 00:22:28,920
# 这是什么？
# 312
# 00:22:28,920 --> 00:22:30,920
# 这是什么？
# 313
# 00:22:30,920 --> 00:22:32,920
# 这是什么？
# 314
# 00:22:32,920 --> 00:22:34,920
# 这是什么？
# 315
# 00:22:34,920 --> 00:22:36,920
# 这是什么？
# 316
# 00:22:36,920 --> 00:22:38,920
# 这是什么？
# 317
# 00:22:38,920 --> 00:22:40,920
# 这是什么？
# 318
# 00:22:40,920 --> 00:22:42,920
# 这是什么？
# 319
# 00:22:42,920 --> 00:22:44,920
# 这是什么？
# 320
# 00:22:44,920 --> 00:22:46,920
# 这是什么？
# 321
# 00:22:46,920 --> 00:22:48,920
# 这是什么？
# 322
# 00:22:48,920 --> 00:22:50,920
# 这是什么？
# 323
# 00:22:50,920 --> 00:22:52,920
# 这是什么？
# 324
# 00:22:52,920 --> 00:22:54,920
# 这是什么？
# 325
# 00:22:54,920 --> 00:22:56,920
# 这是什么？
# 326
# 00:22:56,920 --> 00:22:58,920
# 这是什么？
# 327
# 00:22:58,920 --> 00:23:00,920
# 这是什么？
# 328
# 00:23:00,920 --> 00:23:02,920
# 这是什么？
# 329
# 00:23:02,920 --> 00:23:04,920
# 这是什么？
# 330
# 00:23:04,920 --> 00:23:06,920
# 这是什么？
# 331
# 00:23:06,920 --> 00:23:08,920
# 这是什么？
# 332
# 00:23:08,920 --> 00:23:10,920
# 这是什么？
# 333
# 00:23:10,920 --> 00:23:12,920
# 这是什么？
# 334
# 00:23:12,920 --> 00:23:14,920
# 这是什么？
# 335
# 00:23:14,920 --> 00:23:16,920
# 这是什么？
# 336
# 00:23:16,920 --> 00:23:18,920
# 这是什么？
# 337
# 00:23:18,920 --> 00:23:20,920
# 这是什么？
# 338
# 00:23:20,920 --> 00:23:22,920
# 这是什么？
# 339
# 00:23:22,920 --> 00:23:24,920
# 这是什么？
# 340
# 00:23:24,920 --> 00:23:26,920
# 这是什么？
# 341
# 00:23:26,920 --> 00:23:28,920
# 这是什么？
# 342
# 00:23:28,920 --> 00:23:30,920
# 这是什么？
# 343
# 00:23:30,920 --> 00:23:32,920
# 这是什么？
# 344
# 00:23:32,920 --> 00:23:34,920
# 这是什么？
# 345
# 00:23:34,920 --> 00:23:36,920
# 这是什么？
# 346
# 00:23:36,920 --> 00:23:38,920
# 这是什么？
# 347
# 00:23:38,920 --> 00:23:40,920
# 这是什么？
# 348
# 00:23:40,920 --> 00:23:42,920
# 这是什么？
# 349
# 00:23:42,920 --> 00:23:44,920
# 这是什么？
# 350
# 00:23:44,920 --> 00:23:46,920
# 这是什么？
# 351
# 00:23:46,920 --> 00:23:48,920
# 这是什么？
# 352
# 00:23:48,920 --> 00:23:50,920
# 这是什么？
# 353
# 00:23:50,920 --> 00:23:52,920
# 这是什么？
# 354
# 00:23:52,920 --> 00:23:54,920
# 这是什么？
# 355
# 00:23:54,920 --> 00:23:56,920
# 这是什么？
# 356
# 00:23:56,920 --> 00:23:58,920
# 这是什么？
# 357
# 00:23:58,920 --> 00:24:00,920
# 这是什么？
# 358
# 00:24:00,920 --> 00:24:02,920
# 这是什么？
# 359
# 00:24:02,920 --> 00:24:04,920
# 这是什么？
# 360
# 00:24:04,920 --> 00:24:06,920
# 这是什么？
# 361
# 00:24:06,920 --> 00:24:08,920
# 这是什么？
# 362
# 00:24:08,920 --> 00:24:10,920
# 这是什么？
# 363
# 00:24:10,920 --> 00:24:12,920
# 这是什么？
# 364
# 00:24:12,920 --> 00:24:14,920
# 这是什么？
# 365
# 00:24:14,920 --> 00:24:16,920
# 这是什么？
# 366
# 00:24:16,920 --> 00:24:18,920
# 这是什么？
# 367
# 00:24:18,920 --> 00:24:20,920
# 这是什么？
# 368
# 00:24:20,920 --> 00:24:22,920
# 这是什么？
# 369
# 00:24:22,920 --> 00:24:24,920
# 这是什么？
# 370
# 00:24:24,920 --> 00:24:26,920
# 这是什么？
# 371
# 00:24:26,920 --> 00:24:28,920
# 这是什么？
# 372
# 00:24:28,920 --> 00:24:30,920
# 这是什么？
# 373
# 00:24:30,920 --> 00:24:32,920
# 这是什么？
# 374
# 00:24:32,920 --> 00:24:34,920
# 这是什么？
# 375
# 00:24:34,920 --> 00:24:36,920
# 这是什么？
# 376
# 00:24:36,920 --> 00:24:38,920
# 这是什么？
# 377
# 00:24:38,920 --> 00:24:40,920
# 这是什么？
# 378
# 00:24:40,920 --> 00:24:42,920
# 这是什么？
# 379
# 00:24:42,920 --> 00:24:44,920
# 这是什么？
# 380
# 00:24:44,920 --> 00:24:46,920
# 这是什么？
# 381
# 00:24:46,920 --> 00:24:48,920
# 这是什么？
# 382
# 00:24:48,920 --> 00:24:50,920
# 这是什么？
# 383
# 00:24:50,920 --> 00:24:52,920
# 这是什么？
# 384
# 00:24:52,920 --> 00:24:54,920
# 这是什么？
# 385
# 00:24:54,920 --> 00:24:56,920
# 这是什么？
# 386
# 00:24:56,920 --> 00:24:58,920
# 这是什么？
# 387
# 00:24:58,920 --> 00:25:00,920
# 这是什么？
# 388
# 00:25:00,920 --> 00:25:02,920
# 这是什么？
# 389
# 00:25:02,920 --> 00:25:04,920
# 这是什么？
# 390
# 00:25:04,920 --> 00:25:06,920
# 这是什么？
# 391
# 00:25:06,920 --> 00:25:08,920
# 这是什么？
# 392
# 1
# 00:00:00,000 --> 00:00:13,000
# 我该怎么办...
# 2
# 00:00:13,000 --> 00:00:15,000
# 你在做什么？
# 3
# 00:00:15,000 --> 00:00:24,000
# 呼...
# 4
# 00:00:24,000 --> 00:00:31,000
# 如果你不和我玩手指，我该怎么办？
# 5
# 00:00:31,000 --> 00:00:35,000
# 有点黏糊糊的。
# 6
# 00:00:35,000 --> 00:00:38,000
# 很脏。
# 7
# 00:00:38,000 --> 00:00:50,000
# 我会用舌头舔干净。
# 8
# 00:00:50,000 --> 00:00:53,000
# 为什么？
# 9
# 00:00:53,000 --> 00:00:56,000
# 我会用舌头舔干净。
# 10
# 00:01:23,000 --> 00:01:51,000
# 我会用舌头舔干净。
# 11
# 00:01:51,000 --> 00:01:56,000
# 即使我舔了，还是会出来。
# 12
# 00:02:21,000 --> 00:02:23,000
# 很脏。
# 13
# 00:02:23,000 --> 00:02:25,000
# 很脏吗？
# 14
# 00:02:51,000 --> 00:03:09,000
# 我想要舔更多。
# 15
# 00:03:09,000 --> 00:03:12,000
# 不行吗？
# 16
# 00:03:12,000 --> 00:03:14,000
# 它不动了。
# 17
# 00:03:14,000 --> 00:03:21,000
# 那么，代替...
# 18
# 00:03:21,000 --> 00:03:38,000
# 为什么不在这里睡觉？
# 19
# 00:03:38,000 --> 00:03:45,000
# 感觉不好。
# 20
# 00:03:45,000 --> 00:04:13,000
# 你想要我舔干净吗？
# 21
# 00:04:13,000 --> 00:04:21,000
# 请。
# 22
# 00:04:43,000 --> 00:04:53,000
# 感觉不好。
# 23
# 00:04:53,000 --> 00:05:18,000
# 很脏。
# 24
# 00:05:18,000 --> 00:05:23,000
# 请一边舔一边清理。
# 25
# 00:05:23,000 --> 00:05:41,000
# 好可爱。
# 26
# 00:05:41,000 --> 00:05:51,000
# 很脏。
# 27
# 00:05:51,000 --> 00:06:12,000
# 很脏。
# 28
# 00:06:12,000 --> 00:06:39,000
# 请多舔一点。
# 29
# 00:06:39,000 --> 00:06:50,000
# 你能舔到一定程度吗？
# 30
# 00:06:50,000 --> 00:07:13,000
# 很脏。
# 31
# 00:07:14,000 --> 00:07:40,000
# 感觉不好。
# 32
# 00:07:40,000 --> 00:07:43,000
# 请一边舔一边清理。
# 33
# 00:08:10,000 --> 00:08:38,000
# 很脏。
# 34
# 00:08:39,000 --> 00:09:07,000
# 请一边舔一边清理。
# 35
# 00:09:07,000 --> 00:09:29,000
# 感觉不好。
# 36
# 00:09:29,000 --> 00:09:58,000
# 感觉不好。
# 37
# 00:09:58,000 --> 00:10:06,000
# 感觉不好。
# 38
# 00:10:06,000 --> 00:10:08,000
# 你自己做了又湿了吗？
# 39
# 00:10:08,000 --> 00:10:23,000
# 你自己做了又湿了吗？
# 40
# 00:10:23,000 --> 00:10:33,000
# 你想要我放进你的眼睛里吗？
# 41
# 00:10:33,000 --> 00:10:58,000
# 你想要我放进你的眼睛里吗？
# 42
# 00:10:58,000 --> 00:11:13,000
# 感觉不好。
# 43
# 00:11:13,000 --> 00:11:41,000
# 感觉不好。
# 44
# 00:11:41,000 --> 00:11:54,000
# 感觉不好。
# 45
# 00:11:54,000 --> 00:12:06,000
# 感觉不好。
# 46
# 00:12:06,000 --> 00:12:13,000
# 感觉不好。
# 47
# 00:12:13,000 --> 00:12:15,000
# 你自己做了又湿了吗？
# 48
# 00:12:15,000 --> 00:12:32,000
# 你自己做了又湿了吗？
# 49
# 00:12:32,000 --> 00:13:01,000
# 感觉不好。
# 50
# 00:13:01,000 --> 00:13:11,000
# 感觉不好。
# 51
# 00:13:11,000 --> 00:13:40,000
# 感觉不好。
# 52
# 00:13:40,000 --> 00:13:55,000
# 感觉不好。
# 53
# 00:13:55,000 --> 00:14:15,000
# 感觉不好。
# 54
# 00:14:15,000 --> 00:14:35,000
# 感觉不好。
# 55
# 00:14:35,000 --> 00:14:55,000
# 感觉不好。
# 56
# 00:14:55,000 --> 00:15:05,000
# 感觉不好。
# 57
# 00:15:05,000 --> 00:15:25,000
# 感觉不好。
# 58
# 00:15:25,000 --> 00:15:53,000
# 感觉不好。
# 59
# 00:15:53,000 --> 00:16:21,000
# 感觉不好。
# 60
# 00:16:21,000 --> 00:16:30,000
# 靠在我身上。
# 61
# 00:16:30,000 --> 00:16:32,000
# 太厉害了。
# 62
# 00:16:32,000 --> 00:16:38,000
# 非常紧。
# 63
# 00:16:38,000 --> 00:16:48,000
# 感觉好吗？
# 64
# 00:16:48,000 --> 00:16:55,000
# 非常紧。
# 65
# 00:16:55,000 --> 00:17:17,000
# 感觉好吗？
# 66
# 00:17:17,000 --> 00:17:46,000
# 感觉不好。
# 67
# 00:17:46,000 --> 00:17:48,000
# 感觉不好。
# 68
# 00:17:48,000 --> 00:18:17,000
# 非常紧。
# 69
# 00:18:17,000 --> 00:18:19,000
# 感觉不好。
# 70
# 00:18:47,000 --> 00:18:52,000
# 感觉不好。
# 71
# 00:18:52,000 --> 00:19:02,000
# 感觉不好。
# 72
# 00:19:02,000 --> 00:19:12,000
# 感觉不好。
# 73
# 00:19:12,000 --> 00:19:22,000
# 感觉不好。
# 74
# 00:19:22,000 --> 00:19:32,000
# 感觉不好。
# 75
# 00:19:32,000 --> 00:19:34,000
# 感觉不好。
# 76
# 00:19:34,000 --> 00:19:37,000
# 感觉不好。
# 77
# 00:19:37,000 --> 00:20:00,000
# 感觉不好。
# 1
# 00:00:00,000 --> 00:00:04,600
# 哦天啊。
# 2
# 00:00:04,600 --> 00:00:09,340
# 哦天啊。
# 3
# 00:00:09,340 --> 00:00:13,640
# 好多颤抖。
# 4
# 00:00:13,640 --> 00:00:16,959
# 我爱你。
# 5
# 00:00:16,959 --> 00:00:21,080
# 我爱你。
# 6
# 00:00:21,080 --> 00:00:24,420
# 我爱你。
# 7
# 00:00:24,420 --> 00:00:28,059
# 我爱你。
# 8
# 00:02:58,259 --> 00:03:00,039
# 我爱你。
# 9
# 00:03:19,220 --> 00:03:22,679
# 让我给你挠背。
# 10
# 00:03:29,059 --> 00:03:33,059
# 我太紧张了，吃不下东西。
# 11
# 00:03:51,059 --> 00:03:53,059
# 伸伸腿。
# 12
# 00:03:58,059 --> 00:04:00,059
# 我太紧张了，吃不下东西。
# 13
# 00:04:17,059 --> 00:04:19,059
# 我太紧张了，吃不下东西。
# 14
# 00:04:28,059 --> 00:04:30,059
# 我太紧张了，吃不下东西。
# 15
# 00:04:58,059 --> 00:05:00,059
# 我太紧张了，吃不下东西。
# 16
# 00:05:28,059 --> 00:05:30,059
# 我太紧张了，吃不下东西。
# 17
# 00:05:58,059 --> 00:06:00,059
# 我太紧张了，吃不下东西。
# 18
# 00:06:08,059 --> 00:06:10,059
# 你能把手放在我头上吗？
# 19
# 00:06:10,059 --> 00:06:12,059
# 你能把手放在我头上吗？
# 20
# 00:06:28,059 --> 00:06:30,059
# 我太紧张了，吃不下东西。
# 21
# 00:06:58,059 --> 00:07:00,059
# 我太紧张了，吃不下东西。
# 22
# 00:07:28,059 --> 00:07:30,059
# 我太紧张了，吃不下东西。
# 23
# 00:07:58,059 --> 00:08:00,059
# 我太紧张了，吃不下东西。
# 24
# 00:08:28,059 --> 00:08:30,059
# 我太紧张了，吃不下东西。
# 25
# 00:08:58,059 --> 00:09:00,059
# 我太紧张了，吃不下东西。
# 26
# 00:09:28,059 --> 00:09:30,059
# 我太紧张了，吃不下东西。
# 27
# 00:09:58,059 --> 00:10:00,059
# 我太紧张了，吃不下东西。
# 28
# 00:10:28,059 --> 00:10:30,059
# 我太紧张了，吃不下东西。
# 29
# 00:10:58,059 --> 00:11:00,059
# 我太紧张了，吃不下东西。
# 30
# 00:11:16,059 --> 00:11:18,059
# 我太紧张了，吃不下东西。
# 31
# 00:11:28,059 --> 00:11:30,059
# 我太紧张了，吃不下东西。
# 32
# 00:11:44,059 --> 00:11:46,059
# 我太紧张了，吃不下东西。
# 33
# 00:11:50,059 --> 00:11:52,059
# 我能进去吗？
# 34
# 00:11:52,059 --> 00:11:54,059
# 我能进去吗？
# 35
# 00:11:54,059 --> 00:11:56,059
# 我能进去吗？
# 36
# 00:11:58,059 --> 00:12:00,059
# 我能进去吗？
# 37
# 00:12:00,059 --> 00:12:02,059
# 我能进去吗？
# 38
# 00:12:02,059 --> 00:12:04,059
# 我能进去吗？
# 39
# 00:12:04,059 --> 00:12:06,059
# 我能进去吗？
# 40
# 00:12:06,059 --> 00:12:08,059
# 我能进去吗？
# 41
# 00:12:26,059 --> 00:12:28,059
# 我能进去吗？
# 42
# 00:12:36,059 --> 00:12:38,059
# 我能进去吗？
# 43
# 00:12:52,059 --> 00:12:54,059
# 我能进去吗？
# 44
# 00:13:06,059 --> 00:13:08,059
# 我能进去吗？
# 45
# 00:13:24,059 --> 00:13:26,059
# 我会把它全部吸出来。
# 46
# 00:13:26,059 --> 00:13:28,059
# 我会把它全部吸出来。
# 47
# 00:13:52,059 --> 00:13:54,059
# 我太可爱了，都害怕。
# 48
# 00:13:56,059 --> 00:13:58,059
# 它是什么味道？
# 49
# 00:13:58,059 --> 00:14:00,059
# 它是什么味道？
# 50
# 00:14:00,059 --> 00:14:02,059
# 苦的？
# 51
# 00:14:02,059 --> 00:14:04,059
# 苦的？
# 52
# 00:14:26,059 --> 00:14:28,059
# 我吃够了。
# 53
# 00:14:28,059 --> 00:14:30,059
# 我吃够了。
# 54
# 00:14:30,059 --> 00:14:32,059
# 我吃够了。
# 55
# 00:14:32,059 --> 00:14:34,059
# 我吃够了。
# 56
# 00:14:36,059 --> 00:14:38,059
# 看起来熟了。
# 57
# 00:14:38,059 --> 00:14:40,059
# 看起来熟了。
# 58
# 00:14:42,059 --> 00:14:44,059
# 结束
# 1
# 00:00:00,000 --> 00:00:22,400
# 我。
# 2
# 00:00:22,400 --> 00:00:39,759
# 他是个马屁精。
# 3
# 00:00:39,759 --> 00:00:47,919
# 现在让我们问他几个问题。
# 4
# 00:00:47,919 --> 00:00:54,919
# 首先，让我们问他对自己的新发色有什么感觉。
# 5
# 00:00:54,919 --> 00:01:01,919
# 我不确定他对自己的新发色有什么感觉，所以我要问他几个问题。
# 6
# 00:01:01,919 --> 00:01:06,919
# 首先，让我们问他对自己的新发色有什么感觉。
# 7
# 00:01:06,919 --> 00:01:07,919
# 你好。
# 8
# 00:01:07,919 --> 00:01:08,919
# 什么？
# 9
# 00:01:08,919 --> 00:01:09,919
# 你好。
# 10
# 00:01:09,919 --> 00:01:10,919
# 你好。
# 11
# 00:01:10,919 --> 00:01:18,919
# 你总是看起来很漂亮。
# 12
# 00:01:18,919 --> 00:01:20,919
# 谢谢。
# 13
# 00:01:20,919 --> 00:01:22,919
# 人们经常这么说吗？
# 14
# 00:01:22,919 --> 00:01:24,919
# 不，他们不这么说。
# 15
# 00:01:24,919 --> 00:01:25,919
# 他们不这么说？
# 16
# 00:01:25,919 --> 00:01:26,919
# 不。
# 17
# 00:01:26,919 --> 00:01:33,919
# 你今天来这里是为了什么？
# 18
# 00:01:33,919 --> 00:01:36,919
# 我来这里玩。
# 19
# 00:01:36,919 --> 00:01:37,919
# 玩？
# 20
# 00:01:37,919 --> 00:01:38,919
# 是的。
# 21
# 00:01:39,919 --> 00:01:44,919
# 是什么样的玩？
# 22
# 00:01:44,919 --> 00:01:48,919
# 好玩的玩。
# 23
# 00:01:48,919 --> 00:01:51,919
# 你看起来很开心。
# 24
# 00:01:51,919 --> 00:01:53,919
# 我看起来很开心。
# 25
# 00:01:53,919 --> 00:01:58,919
# 那里有什么样的人？
# 26
# 00:01:58,919 --> 00:02:06,919
# 高个子的人。
# 27
# 00:02:06,919 --> 00:02:09,919
# 戴口罩的人。
# 28
# 00:02:09,919 --> 00:02:11,919
# 他们可疑吗？
# 29
# 00:02:11,919 --> 00:02:12,919
# 可疑。
# 30
# 00:02:12,919 --> 00:02:13,919
# 可疑？
# 31
# 00:02:13,919 --> 00:02:14,919
# 是的。
# 32
# 00:02:14,919 --> 00:02:19,919
# 那么，我要问你一个有趣的问题。
# 33
# 00:02:19,919 --> 00:02:20,919
# 好的。
# 34
# 00:02:20,919 --> 00:02:21,919
# 你准备好了吗？
# 35
# 00:02:21,919 --> 00:02:22,919
# 好的。
# 36
# 00:02:22,919 --> 00:02:25,919
# 请开始。
# 37
# 00:02:25,919 --> 00:02:26,919
# 你好。
# 38
# 00:02:26,919 --> 00:02:27,919
# 你好。
# 39
# 00:02:27,919 --> 00:02:28,919
# 你是个可疑的人。
# 40
# 00:02:28,919 --> 00:02:29,919
# 是的，我是。
# 41
# 00:02:29,919 --> 00:02:31,919
# 你太可爱了。
# 42
# 00:02:31,919 --> 00:02:33,919
# 谢谢。
# 43
# 00:02:33,919 --> 00:02:35,919
# 你多大了？
# 44
# 00:02:35,919 --> 00:02:36,919
# 我22岁。
# 45
# 00:02:36,919 --> 00:02:37,919
# 22岁。
# 46
# 00:02:37,919 --> 00:02:38,919
# 我明白了。
# 47
# 00:02:38,919 --> 00:02:41,919
# 那是什么意思？
# 48
# 00:02:41,919 --> 00:02:42,919
# 你是社交工作者吗？
# 49
# 00:02:42,919 --> 00:02:44,919
# 我是大四的大学生。
# 50
# 00:02:44,919 --> 00:02:45,919
# 大四的大学生？
# 51
# 00:02:45,919 --> 00:02:46,919
# 是的。
# 52
# 00:02:46,919 --> 00:02:54,919
# 我不知道你在大四的时候玩得这么开心。
# 53
# 00:02:54,919 --> 00:02:57,919
# 你有点炫耀，不是吗？
# 54
# 00:02:57,919 --> 00:02:58,919
# 有点。
# 55
# 00:02:58,919 --> 00:02:59,919
# 只有一点？
# 56
# 00:02:59,919 --> 00:03:00,919
# 是的。
# 57
# 00:03:01,919 --> 00:03:02,919
# 我明白了。
# 58
# 00:03:02,919 --> 00:03:10,919
# 如果你是这样一个漂亮的女孩，即使你不这样玩，很多男孩也会来找你。
# 59
# 00:03:10,919 --> 00:03:12,919
# 不，他们不会。
# 60
# 00:03:12,919 --> 00:03:13,919
# 什么？
# 61
# 00:03:13,919 --> 00:03:16,919
# 我觉得你周围没有人注意你。
# 62
# 00:03:16,919 --> 00:03:17,919
# 我明白了。
# 63
# 00:03:17,919 --> 00:03:19,919
# 不。
# 64
# 00:03:19,919 --> 00:03:25,919
# 那么，今天我要和一个没有注意力的男孩聊天。
# 65
# 00:03:25,919 --> 00:03:27,919
# 好的。
# 66
# 00:03:28,919 --> 00:03:30,919
# 你的皮肤真白真漂亮。
# 67
# 00:03:30,919 --> 00:03:32,919
# 脏了。
# 68
# 00:03:32,919 --> 00:03:33,919
# 为什么？
# 69
# 00:03:33,919 --> 00:03:35,919
# 为什么你不那么自信？
# 70
# 00:03:35,919 --> 00:03:37,919
# 我不自信。
# 71
# 00:03:39,919 --> 00:03:41,919
# 你太可爱了。
# 72
# 00:03:41,919 --> 00:03:42,919
# 是的。
# 73
# 00:03:47,919 --> 00:03:50,919
# 你的嘴唇小而可爱。
# 74
# 00:03:57,919 --> 00:03:58,919
# 是的。
# 75
# 00:04:57,920 --> 00:04:59,920
# 你的嘴唇很柔软。
# 76
# 00:05:02,920 --> 00:05:04,920
# 你有多少男孩？
# 77
# 00:05:04,920 --> 00:05:05,920
# 不多。
# 78
# 00:05:05,920 --> 00:05:06,920
# 什么？
# 79
# 00:05:06,920 --> 00:05:07,920
# 不多。
# 80
# 00:05:07,920 --> 00:05:08,920
# 不多？
# 81
# 00:05:08,920 --> 00:05:09,920
# 是的。
# 82
# 00:05:09,920 --> 00:05:10,920
# 大约五个？
# 83
# 00:05:10,920 --> 00:05:12,920
# 我不知道。
# 84
# 00:05:12,920 --> 00:05:13,920
# 你不知道？
# 85
# 00:05:14,920 --> 00:05:16,920
# 我想知道你有多少男孩。
# 86
# 00:05:17,920 --> 00:05:20,920
# 那么，今天我要和一个没有注意力的男孩聊天。
# 87
# 00:05:21,920 --> 00:05:22,920
# 我明白了。
# 88
# 00:05:24,920 --> 00:05:26,920
# 我很兴奋。
# 89
# 00:05:28,920 --> 00:05:30,920
# 你有好的风格。
# 90
# 00:05:31,920 --> 00:05:33,920
# 你身材很好。
# 91
# 00:05:35,920 --> 00:05:37,920
# 你有很多胸部。
# 92
# 00:05:43,920 --> 00:05:45,920
# 你喜欢什么样的风格？
# 93
# 00:05:47,920 --> 00:05:48,920
# 什么？
# 94
# 00:05:49,920 --> 00:05:51,920
# 你胸口有什么感觉吗？
# 95
# 00:05:52,920 --> 00:05:53,920
# 我喜欢温柔的风格。
# 96
# 00:05:53,920 --> 00:05:55,920
# 温柔的风格？
# 97
# 00:05:55,920 --> 00:05:56,920
# 别担心。
# 98
# 00:05:56,920 --> 00:05:58,920
# 我有温柔的风格。
# 99
# 00:06:01,920 --> 00:06:03,920
# 你还有其他敏感的地方吗？
# 100
# 00:06:04,920 --> 00:06:06,920
# 像耳朵或脖子？
# 101
# 00:06:07,920 --> 00:06:08,920
# 痒。
# 102
# 00:06:08,920 --> 00:06:09,920
# 真的吗？
# 103
# 00:06:09,920 --> 00:06:10,920
# 是的。
# 104
# 00:06:10,920 --> 00:06:11,920
# 让我看看你的脖子。
# 105
# 00:06:19,920 --> 00:06:20,920
# 痒。
# 106
# 00:06:20,920 --> 00:06:22,920
# 痒吗？
# 107
# 00:06:22,920 --> 00:06:24,920
# 痒吗？
# 108
# 00:06:24,920 --> 00:06:25,920
# 痒。
# 109
# 00:06:29,920 --> 00:06:31,920
# 你太可爱了。
# 110
# 00:06:33,920 --> 00:06:34,920
# 是的。
# 111
# 00:06:47,920 --> 00:06:50,920
# 你的嘴唇又软又滑。
# 112
# 00:06:56,920 --> 00:06:57,920
# 你做了什么？
# 113
# 00:06:58,920 --> 00:06:59,920
# 很尴尬。
# 114
# 00:06:59,920 --> 00:07:01,920
# 是吗？
# 115
# 00:07:00,920 --> 00:07:02,920
# 我睁开了一点眼睛。
# 116
# 00:07:08,920 --> 00:07:10,920
# 你找到了一个可爱的人。
# 117
# 00:07:15,920 --> 00:07:17,920
# 你找到了一个可爱的人。
# 118
# 00:07:40,920 --> 00:07:42,920
# 你通常有一个大肚子。
# 119
# 00:07:43,920 --> 00:07:44,920
# 你喜欢什么？
# 120
# 00:07:44,920 --> 00:07:46,920
# 我喜欢巧克力。
# 121
# 00:07:46,920 --> 00:07:47,920
# 用手指吗？
# 122
# 00:07:47,920 --> 00:07:48,920
# 是的。
# 123
# 00:07:48,920 --> 00:07:50,920
# 你要用手指吃巧克力。
# 124
# 00:07:50,920 --> 00:07:52,920
# 你喜欢巧克力吗？
# 125
# 00:07:52,920 --> 00:07:53,920
# 是的。
# 126
# 00:08:13,920 --> 00:08:14,920
# 痒。
# 127
# 00:08:29,920 --> 00:08:31,920
# 你很可爱，但又很色情。
# 128
# 00:08:33,919 --> 00:08:35,919
# 让我们脱掉你的衣服。
# 129
# 00:08:36,919 --> 00:08:37,919
# 很困难。
# 130
# 00:08:37,919 --> 00:08:38,919
# 为什么？
# 131
# 00:08:39,919 --> 00:08:41,919
# 让我看看你的脸。
# 132
# 00:08:52,919 --> 00:08:54,919
# 你有一个大肚子。
# 133
# 00:08:55,919 --> 00:08:56,919
# 痒。
# 134
# 00:08:56,919 --> 00:08:57,919
# 软软的。
# 135
# 00:09:03,919 --> 00:09:05,919
# 你喜欢什么？
# 136
# 00:09:05,919 --> 00:09:06,919
# 你喜欢吗？
# 137
# 00:09:07,919 --> 00:09:09,919
# 你喜欢什么样的？
# 138
# 00:09:14,919 --> 00:09:16,919
# 你有一个软软的肚子。
# 139
# 00:09:16,919 --> 00:09:17,919
# 很漂亮。
# 140
# 00:09:22,919 --> 00:09:24,919
# 让我看看你的肚子。
# 141
# 00:09:27,919 --> 00:09:29,919
# 请抬起头。
# 142
# 00:09:35,919 --> 00:09:36,919
# 很漂亮。
# 143
# 00:09:37,919 --> 00:09:39,919
# 请站起来。
# 144
# 00:09:43,919 --> 00:09:45,919
# 很漂亮。
# 145
# 00:09:46,919 --> 00:09:48,919
# 你有一个好身材。
# 146
# 00:09:49,919 --> 00:09:50,919
# 你尴尬吗？
# 147
# 00:09:51,919 --> 00:09:53,919
# 让我看看你的屁股。
# 148
# 00:09:54,919 --> 00:09:55,919
# 别这样。
# 149
# 00:09:55,919 --> 00:09:56,919
# 别这样。
# 150
# 00:10:06,919 --> 00:10:08,919
# 你有一个软软的屁股。
# 151
# 00:10:22,919 --> 00:10:24,919
# 我不想碰你软软的屁股。
# 152
# 00:10:35,919 --> 00:10:36,919
# 痒。
# 153
# 00:11:06,919 --> 00:11:07,919
# 你喜欢吗？
# 154
# 00:11:07,919 --> 00:11:08,919
# 是的。
# 155
# 00:11:08,919 --> 00:11:09,919
# 很漂亮。
# 156
# 00:11:13,919 --> 00:11:14,919
# 痒。
# 157
# 00:11:25,919 --> 00:11:26,919
# 痒，对吧？
# 158
# 00:11:26,919 --> 00:11:27,919
# 是的。
# 159
# 00:11:35,919 --> 00:11:36,919
# 痒，对吧？
# 160
# 00:11:36,919 --> 00:11:37,919
# 是的。
# 161
# 00:12:02,919 --> 00:12:03,919
# 痒。
# 162
# 00:12:06,919 --> 00:12:08,919
# 我没说我不喜欢。
# 163
# 00:12:18,919 --> 00:12:20,919
# 我没说我不喜欢。
# 164
# 00:12:26,919 --> 00:12:28,919
# 很漂亮。
# 165
# 00:12:36,919 --> 00:12:37,919
# 痒。
# 166
# 00:12:39,919 --> 00:12:40,919
# 痒。
# 167
# 00:12:47,919 --> 00:12:48,919
# 你不喜欢吗？
# 168
# 00:12:50,919 --> 00:12:52,919
# 我没说我不喜欢。
# 169
# 00:12:52,919 --> 00:12:53,919
# 很硬。
# 170
# 00:12:58,919 --> 00:12:59,919
# 很硬。
# 171
# 00:12:59,919 --> 00:13:00,919
# 你不喜欢吗？
# 172
# 00:13:05,919 --> 00:13:06,919
# 很硬。
# 173
# 00:13:08,919 --> 00:13:09,919
# 很硬。
# 174
# 00:13:14,919 --> 00:13:16,919
# 你喜欢什么样的？
# 175
# 00:13:19,919 --> 00:13:20,919
# 我想摸摸它。
# 176
# 00:13:20,919 --> 00:13:21,919
# 你想摸摸它吗？
# 177
# 00:13:22,919 --> 00:13:23,919
# 你想摸摸它吗？
# 178
# 00:13:23,919 --> 00:13:24,919
# 你想摸摸它吗？
# 179
# 00:13:24,919 --> 00:13:25,919
# 你想摸摸它吗？
# 180
# 00:13:25,919 --> 00:13:26,919
# 你想摸摸它吗？
# 181
# 00:14:06,919 --> 00:14:07,919
# 你喜欢什么样的？
# 182
# 00:14:07,919 --> 00:14:08,919
# 我想摸摸它。
# 183
# 00:14:08,919 --> 00:14:09,919
# 你喜欢吗？
# 184
# 00:14:09,919 --> 00:14:10,919
# 我想摸摸它。
# 185
# 00:14:10,919 --> 00:14:11,919
# 你喜欢吗？
# 186
# 00:14:11,919 --> 00:14:12,919
# 我想摸摸它。
# 187
# 00:14:12,919 --> 00:14:13,919
# 你喜欢吗？
# 188
# 00:14:13,919 --> 00:14:14,919
# 我想摸摸它。
# 189
# 00:14:14,919 --> 00:14:15,919
# 你喜欢吗？
# 190
# 00:14:15,919 --> 00:14:16,919
# 我想摸摸它。
# 191
# 00:14:19,919 --> 00:14:21,919
# 这次我要留下来，给他们一个吻。
# 192
# 00:14:21,919 --> 00:14:22,919
# 你更喜欢喜欢还是讨厌。
# 193
# 00:14:22,919 --> 00:14:23,919
# 你更喜欢喜欢还是讨厌。
# 194
# 00:14:23,919 --> 00:14:24,919
# 非常好。
# 195
# 00:14:24,919 --> 00:14:25,919
# 小心。
# 196
# 00:14:25,919 --> 00:14:28,919
# 这次我要留下来，给他们一个吻。
# 197
# 00:14:55,919 --> 00:14:57,919
# 这次我要留下来，给他们一个吻。
# 198
# 00:15:25,919 --> 00:15:26,919
# 这次我要留下来，给他们一个吻。
# 199
# 00:15:29,919 --> 00:15:30,919
# 你想让我拍拍你的胸部吗？
# 200
# 00:15:30,919 --> 00:15:31,919
# 你想让我拍拍你的胸部吗？
# 201
# 00:15:33,919 --> 00:15:34,919
# 太可爱了。
# 202
# 00:15:34,919 --> 00:15:35,919
# 太可爱了。
# 203
# 00:16:04,919 --> 00:16:05,919
# 看起来真的很软。
# 204
# 00:16:13,919 --> 00:16:15,919
# 看起来真的很软。
# 205
# 00:16:18,919 --> 00:16:20,919
# 你满意吗？
# 206
# 00:16:23,919 --> 00:16:26,919
# 这是什么？
# 207
# 00:16:35,919 --> 00:16:40,919
# 发生了什么？
# 208
# 00:16:41,919 --> 00:16:44,919
# 为什么你说你不喜欢那里？
# 209
# 00:16:52,919 --> 00:16:54,919
# 你不想看吗？
# 210
# 00:16:57,919 --> 00:16:59,919
# 让我们看看这边。
# 211
# 00:16:59,919 --> 00:17:01,919
# 这真是太棒了。
# 212
# 00:17:05,920 --> 00:17:07,920
# 很湿。
# 213
# 00:17:13,920 --> 00:17:15,920
# 看这个，太棒了。
# 214
# 00:17:22,920 --> 00:17:25,920
# 如果这是内衣，那这是什么？
# 215
# 00:17:26,920 --> 00:17:28,920
# 嘿。
# 216
# 00:17:30,920 --> 00:17:32,920
# 让我看看。
# 217
# 00:17:32,920 --> 00:17:34,920
# 让我看看。
# 218
# 00:17:37,920 --> 00:17:39,920
# 不，我要用脚把它藏起来。
# 219
# 00:17:39,920 --> 00:17:41,920
# 我不想。
# 220
# 00:17:47,920 --> 00:17:50,920
# 等一下。我拉了很多线。
# 221
# 00:17:50,920 --> 00:17:52,920
# 我不想。
# 222
# 00:17:53,920 --> 00:17:55,920
# 等一下。
# 223
# 00:17:55,920 --> 00:17:57,920
# 这是不是太湿了？
# 224
# 00:18:01,920 --> 00:18:03,920
# 太棒了。
# 225
# 00:18:06,920 --> 00:18:08,920
# 真是太棒了。
# 226
# 00:18:10,920 --> 00:18:11,920
# 展开得牢牢的。
# 227
# 00:18:11,920 --> 00:18:13,920
# 我的手指滑溜溜的。
# 228
# 00:18:23,920 --> 00:18:25,920
# 真是太棒了。
# 229
# 00:18:30,920 --> 00:18:32,920
# 为什么这么湿？
# 230
# 00:18:32,920 --> 00:18:34,920
# 真是太棒了。
# 231
# 00:18:37,920 --> 00:18:39,920
# 真是太棒了。
# 232
# 00:18:52,920 --> 00:18:54,920
# 真是太棒了。
# 233
# 00:19:13,920 --> 00:19:15,920
# 真是太棒了。
# 234
# 00:19:16,920 --> 00:19:18,920
# 真是太棒了。
# 235
# 00:19:18,920 --> 00:19:20,920
# 真是太棒了。
# 236
# 00:19:21,920 --> 00:19:22,920
# 我明白了。
# 237
# 00:19:22,920 --> 00:19:24,920
# 是入口吗？
# 238
# 00:19:24,920 --> 00:19:26,920
# 还是后面？
# 239
# 00:19:26,920 --> 00:19:28,920
# 是外面吗？
# 240
# 00:19:41,920 --> 00:19:43,920
# 非常滑。
# 241
# 00:19:48,920 --> 00:19:50,920
# 看这个，太棒了。
# 242
# 00:19:55,920 --> 00:19:57,920
# 等一下。我拉了很多线。
# 243
# 00:19:57,920 --> 00:19:59,920
# 我不想。
# 244
# 00:20:00,920 --> 00:20:02,920
# 等一下。
# 245
# 00:20:02,920 --> 00:20:04,920
# 这是不是太湿了？
# 246
# 00:20:08,920 --> 00:20:10,920
# 太棒了。
# 247
# 00:20:13,920 --> 00:20:15,920
# 这是什么？
# 248
# 00:20:20,920 --> 00:20:22,920
# 这是什么？
# 249
# 00:20:22,920 --> 00:20:24,920
# 这是什么？
# 250
# 00:20:24,920 --> 00:20:26,920
# 这是什么？
# 251
# 00:20:26,920 --> 00:20:28,920
# 这是什么？
# 252
# 00:20:28,920 --> 00:20:30,920
# 这是什么？
# 253
# 00:20:30,920 --> 00:20:32,920
# 这是什么？
# 254
# 00:20:32,920 --> 00:20:34,920
# 这是什么？
# 255
# 00:20:34,920 --> 00:20:36,920
# 这是什么？
# 256
# 00:20:36,920 --> 00:20:38,920
# 这是什么？
# 257
# 00:20:38,920 --> 00:20:40,920
# 这是什么？
# 258
# 00:20:40,920 --> 00:20:42,920
# 这是什么？
# 259
# 00:20:42,920 --> 00:20:44,920
# 这是什么？
# 260
# 00:20:44,920 --> 00:20:46,920
# 这是什么？
# 261
# 00:20:46,920 --> 00:20:48,920
# 这是什么？
# 262
# 00:20:48,920 --> 00:20:50,920
# 这是什么？
# 263
# 00:20:50,920 --> 00:20:52,920
# 这是什么？
# 264
# 00:20:52,920 --> 00:20:54,920
# 这是什么？
# 265
# 00:20:54,920 --> 00:20:56,920
# 这是什么？
# 266
# 00:20:56,920 --> 00:20:58,920
# 这是什么？
# 267
# 00:20:58,920 --> 00:21:00,920
# 这是什么？
# 268
# 00:21:00,920 --> 00:21:02,920
# 这是什么？
# 269
# 00:21:02,920 --> 00:21:04,920
# 这是什么？
# 270
# 00:21:04,920 --> 00:21:06,920
# 这是什么？
# 271
# 00:21:06,920 --> 00:21:08,920
# 这是什么？
# 272
# 00:21:08,920 --> 00:21:10,920
# 这是什么？
# 273
# 00:21:10,920 --> 00:21:12,920
# 这是什么？
# 274
# 00:21:12,920 --> 00:21:14,920
# 这是什么？
# 275
# 00:21:14,920 --> 00:21:16,920
# 这是什么？
# 276
# 00:21:16,920 --> 00:21:18,920
# 这是什么？
# 277
# 00:21:18,920 --> 00:21:20,920
# 这是什么？
# 278
# 00:21:20,920 --> 00:21:22,920
# 这是什么？
# 279
# 00:21:22,920 --> 00:21:24,920
# 这是什么？
# 280
# 00:21:24,920 --> 00:21:26,920
# 这是什么？
# 281
# 00:21:26,920 --> 00:21:28,920
# 这是什么？
# 282
# 00:21:28,920 --> 00:21:30,920
# 这是什么？
# 283
# 00:21:30,920 --> 00:21:32,920
# 这是什么？
# 284
# 00:21:32,920 --> 00:21:34,920
# 这是什么？
# 285
# 00:21:34,920 --> 00:21:36,920
# 这是什么？
# 286
# 00:21:36,920 --> 00:21:38,920
# 这是什么？
# 287
# 00:21:38,920 --> 00:21:40,920
# 这是什么？
# 288
# 00:21:40,920 --> 00:21:42,920
# 这是什么？
# 289
# 00:21:42,920 --> 00:21:44,920
# 这是什么？
# 290
# 00:21:44,920 --> 00:21:46,920
# 这是什么？
# 291
# 00:21:46,920 --> 00:21:48,920
# 这是什么？
# 292
# 00:21:48,920 --> 00:21:50,920
# 这是什么？
# 293
# 00:21:50,920 --> 00:21:52,920
# 这是什么？
# 294
# 00:21:52,920 --> 00:21:54,920
# 这是什么？
# 295
# 00:21:54,920 --> 00:21:56,920
# 这是什么？
# 296
# 00:21:56,920 --> 00:21:58,920
# 这是什么？
# 297
# 00:21:58,920 --> 00:22:00,920
# 这是什么？
# 298
# 00:22:00,920 --> 00:22:02,920
# 这是什么？
# 299
# 00:22:02,920 --> 00:22:04,920
# 这是什么？
# 300
# 00:22:04,920 --> 00:22:06,920
# 这是什么？
# 301
# 00:22:06,920 --> 00:22:08,920
# 这是什么？
# 302
# 00:22:08,920 --> 00:22:10,920
# 这是什么？
# 303
# 00:22:10,920 --> 00:22:12,920
# 这是什么？
# 304
# 00:22:12,920 --> 00:22:14,920
# 这是什么？
# 305
# 00:22:14,920 --> 00:22:16,920
# 这是什么？
# 306
# 00:22:16,920 --> 00:22:18,920
# 这是什么？
# 307
# 00:22:18,920 --> 00:22:20,920
# 这是什么？
# 308
# 00:22:20,920 --> 00:22:22,920
# 这是什么？
# 309
# 00:22:22,920 --> 00:22:24,920
# 这是什么？
# 310
# 00:22:24,920 --> 00:22:26,920
# 这是什么？
# 311
# 00:22:26,920 --> 00:22:28,920
# 这是什么？
# 312
# 00:22:28,920 --> 00:22:30,920
# 这是什么？
# 313
# 00:22:30,920 --> 00:22:32,920
# 这是什么？
# 314
# 00:22:32,920 --> 00:22:34,920
# 这是什么？
# 315
# 00:22:34,920 --> 00:22:36,920
# 这是什么？
# 316
# 00:22:36,920 --> 00:22:38,920
# 这是什么？
# 317
# 00:22:38,920 --> 00:22:40,920
# 这是什么？
# 318
# 00:22:40,920 --> 00:22:42,920
# 这是什么？
# 319
# 00:22:42,920 --> 00:22:44,920
# 这是什么？
# 320
# 00:22:44,920 --> 00:22:46,920
# 这是什么？
# 321
# 00:22:46,920 --> 00:22:48,920
# 这是什么？
# 322
# 00:22:48,920 --> 00:22:50,920
# 这是什么？
# 323
# 00:22:50,920 --> 00:22:52,920
# 这是什么？
# 324
# 00:22:52,920 --> 00:22:54,920
# 这是什么？
# 325
# 00:22:54,920 --> 00:22:56,920
# 这是什么？
# 326
# 00:22:56,920 --> 00:22:58,920
# 这是什么？
# 327
# 00:22:58,920 --> 00:23:00,920
# 这是什么？
# 328
# 00:23:00,920 --> 00:23:02,920
# 这是什么？
# 329
# 00:23:02,920 --> 00:23:04,920
# 这是什么？
# 330
# 00:23:04,920 --> 00:23:06,920
# 这是什么？
# 331
# 00:23:06,920 --> 00:23:08,920
# 这是什么？
# 332
# 00:23:08,920 --> 00:23:10,920
# 这是什么？
# 333
# 00:23:10,920 --> 00:23:12,920
# 这是什么？
# 334
# 00:23:12,920 --> 00:23:14,920
# 这是什么？
# 335
# 00:23:14,920 --> 00:23:16,920
# 这是什么？
# 336
# 00:23:16,920 --> 00:23:18,920
# 这是什么？
# 337
# 00:23:18,920 --> 00:23:20,920
# 这是什么？
# 338
# 00:23:20,920 --> 00:23:22,920
# 这是什么？
# 339
# 00:23:22,920 --> 00:23:24,920
# 这是什么？
# 340
# 00:23:24,920 --> 00:23:26,920
# 这是什么？
# 341
# 00:23:26,920 --> 00:23:28,920
# 这是什么？
# 342
# 00:23:28,920 --> 00:23:30,920
# 这是什么？
# 343
# 00:23:30,920 --> 00:23:32,920
# 这是什么？
# 344
# 00:23:32,920 --> 00:23:34,920
# 这是什么？
# 345
# 00:23:34,920 --> 00:23:36,920
# 这是什么？
# 346
# 00:23:36,920 --> 00:23:38,920
# 这是什么？
# 347
# 00:23:38,920 --> 00:23:40,920
# 这是什么？
# 348
# 00:23:40,920 --> 00:23:42,920
# 这是什么？
# 349
# 00:23:42,920 --> 00:23:44,920
# 这是什么？
# 350
# 00:23:44,920 --> 00:23:46,920
# 这是什么？
# 351
# 00:23:46,920 --> 00:23:48,920
# 这是什么？
# 352
# 00:23:48,920 --> 00:23:50,920
# 这是什么？
# 353
# 00:23:50,920 --> 00:23:52,920
# 这是什么？
# 354
# 00:23:52,920 --> 00:23:54,920
# 这是什么？
# 355
# 00:23:54,920 --> 00:23:56,920
# 这是什么？
# 356
# 00:23:56,920 --> 00:23:58,920
# 这是什么？
# 357
# 00:23:58,920 --> 00:24:00,920
# 这是什么？
# 358
# 00:24:00,920 --> 00:24:02,920
# 这是什么？
# 359
# 00:24:02,920 --> 00:24:04,920
# 这是什么？
# 360
# 00:24:04,920 --> 00:24:06,920
# 这是什么？
# 361
# 00:24:06,920 --> 00:24:08,920
# 这是什么？
# 362
# 00:24:08,920 --> 00:24:10,920
# 这是什么？
# 363
# 00:24:10,920 --> 00:24:12,920
# 这是什么？
# 364
# 00:24:12,920 --> 00:24:14,920
# 这是什么？
# 365
# 00:24:14,920 --> 00:24:16,920
# 这是什么？
# 366
# 00:24:16,920 --> 00:24:18,920
# 这是什么？
# 367
# 00:24:18,920 --> 00:24:20,920
# 这是什么？
# 368
# 00:24:20,920 --> 00:24:22,920
# 这是什么？
# 369
# 00:24:22,920 --> 00:24:24,920
# 这是什么？
# 370
# 00:24:24,920 --> 00:24:26,920
# 这是什么？
# 371
# 00:24:26,920 --> 00:24:28,920
# 这是什么？
# 372
# 00:24:28,920 --> 00:24:30,920
# 这是什么？
# 373
# 00:24:30,920 --> 00:24:32,920
# 这是什么？
# 374
# 00:24:32,920 --> 00:24:34,920
# 这是什么？
# 375
# 00:24:34,920 --> 00:24:36,920
# 这是什么？
# 376
# 00:24:36,920 --> 00:24:38,920
# 这是什么？
# 377
# 00:24:38,920 --> 00:24:40,920
# 这是什么？
# 378
# 00:24:40,920 --> 00:24:42,920
# 这是什么？
# 379
# 00:24:42,920 --> 00:24:44,920
# 这是什么？
# 380
# 00:24:44,920 --> 00:24:46,920
# 这是什么？
# 381
# 00:24:46,920 --> 00:24:48,920
# 这是什么？
# 382
# 00:24:48,920 --> 00:24:50,920
# 这是什么？
# 383
# 00:24:50,920 --> 00:24:52,920
# 这是什么？
# 384
# 00:24:52,920 --> 00:24:54,920
# 这是什么？
# 385
# 00:24:54,920 --> 00:24:56,920
# 这是什么？
# 386
# 00:24:56,920 --> 00:24:58,920
# 这是什么？
# 387
# 00:24:58,920 --> 00:25:00,920
# 这是什么？
# 388
# 00:25:00,920 --> 00:25:02,920
# 这是什么？
# 389
# 00:25:02,920 --> 00:25:04,920
# 这是什么？
# 390
# 00:25:04,920 --> 00:25:06,920
# 这是什么？
# 391
# 00:25:06,920 --> 00:25:08,920
# 这是什么？
# 392
# 1
# 00:00:00,000 --> 00:00:13,000
# 我该怎么办...
# 2
# 00:00:13,000 --> 00:00:15,000
# 你在做什么？
# 3
# 00:00:15,000 --> 00:00:24,000
# 呼...
# 4
# 00:00:24,000 --> 00:00:31,000
# 如果你不和我玩手指，我该怎么办？
# 5
# 00:00:31,000 --> 00:00:35,000
# 有点黏糊糊的。
# 6
# 00:00:35,000 --> 00:00:38,000
# 很脏。
# 7
# 00:00:38,000 --> 00:00:50,000
# 我会用舌头舔干净。
# 8
# 00:00:50,000 --> 00:00:53,000
# 为什么？
# 9
# 00:00:53,000 --> 00:00:56,000
# 我会用舌头舔干净。
# 10
# 00:01:23,000 --> 00:01:51,000
# 我会用舌头舔干净。
# 11
# 00:01:51,000 --> 00:01:56,000
# 即使我舔了，还是会出来。
# 12
# 00:02:21,000 --> 00:02:23,000
# 很脏。
# 13
# 00:02:23,000 --> 00:02:25,000
# 很脏吗？
# 14
# 00:02:51,000 --> 00:03:09,000
# 我想要舔更多。
# 15
# 00:03:09,000 --> 00:03:12,000
# 不行吗？
# 16
# 00:03:12,000 --> 00:03:14,000
# 它不动了。
# 17
# 00:03:14,000 --> 00:03:21,000
# 那么，代替...
# 18
# 00:03:21,000 --> 00:03:38,000
# 为什么不在这里睡觉？
# 19
# 00:03:38,000 --> 00:03:45,000
# 感觉不好。
# 20
# 00:03:45,000 --> 00:04:13,000
# 你想要我舔干净吗？
# 21
# 00:04:13,000 --> 00:04:21,000
# 请。
# 22
# 00:04:43,000 --> 00:04:53,000
# 感觉不好。
# 23
# 00:04:53,000 --> 00:05:18,000
# 很脏。
# 24
# 00:05:18,000 --> 00:05:23,000
# 请一边舔一边清理。
# 25
# 00:05:23,000 --> 00:05:41,000
# 好可爱。
# 26
# 00:05:41,000 --> 00:05:51,000
# 很脏。
# 27
# 00:05:51,000 --> 00:06:12,000
# 很脏。
# 28
# 00:06:12,000 --> 00:06:39,000
# 请多舔一点。
# 29
# 00:06:39,000 --> 00:06:50,000
# 你能舔到一定程度吗？
# 30
# 00:06:50,000 --> 00:07:13,000
# 很脏。
# 31
# 00:07:14,000 --> 00:07:40,000
# 感觉不好。
# 32
# 00:07:40,000 --> 00:07:43,000
# 请一边舔一边清理。
# 33
# 00:08:10,000 --> 00:08:38,000
# 很脏。
# 34
# 00:08:39,000 --> 00:09:07,000
# 请一边舔一边清理。
# 35
# 00:09:07,000 --> 00:09:29,000
# 感觉不好。
# 36
# 00:09:29,000 --> 00:09:58,000
# 感觉不好。
# 37
# 00:09:58,000 --> 00:10:06,000
# 感觉不好。
# 38
# 00:10:06,000 --> 00:10:08,000
# 你自己做了又湿了吗？
# 39
# 00:10:08,000 --> 00:10:23,000
# 你自己做了又湿了吗？
# 40
# 00:10:23,000 --> 00:10:33,000
# 你想要我放进你的眼睛里吗？
# 41
# 00:10:33,000 --> 00:10:58,000
# 你想要我放进你的眼睛里吗？
# 42
# 00:10:58,000 --> 00:11:13,000
# 感觉不好。
# 43
# 00:11:13,000 --> 00:11:41,000
# 感觉不好。
# 44
# 00:11:41,000 --> 00:11:54,000
# 感觉不好。
# 45
# 00:11:54,000 --> 00:12:06,000
# 感觉不好。
# 46
# 00:12:06,000 --> 00:12:13,000
# 感觉不好。
# 47
# 00:12:13,000 --> 00:12:15,000
# 你自己做了又湿了吗？
# 48
# 00:12:15,000 --> 00:12:32,000
# 你自己做了又湿了吗？
# 49
# 00:12:32,000 --> 00:13:01,000
# 感觉不好。
# 50
# 00:13:01,000 --> 00:13:11,000
# 感觉不好。
# 51
# 00:13:11,000 --> 00:13:40,000
# 感觉不好。
# 52
# 00:13:40,000 --> 00:13:55,000
# 感觉不好。
# 53
# 00:13:55,000 --> 00:14:15,000
# 感觉不好。
# 54
# 00:14:15,000 --> 00:14:35,000
# 感觉不好。
# 55
# 00:14:35,000 --> 00:14:55,000
# 感觉不好。
# 56
# 00:14:55,000 --> 00:15:05,000
# 感觉不好。
# 57
# 00:15:05,000 --> 00:15:25,000
# 感觉不好。
# 58
# 00:15:25,000 --> 00:15:53,000
# 感觉不好。
# 59
# 00:15:53,000 --> 00:16:21,000
# 感觉不好。
# 60
# 00:16:21,000 --> 00:16:30,000
# 靠在我身上。
# 61
# 00:16:30,000 --> 00:16:32,000
# 太厉害了。
# 62
# 00:16:32,000 --> 00:16:38,000
# 非常紧。
# 63
# 00:16:38,000 --> 00:16:48,000
# 感觉好吗？
# 64
# 00:16:48,000 --> 00:16:55,000
# 非常紧。
# 65
# 00:16:55,000 --> 00:17:17,000
# 感觉好吗？
# 66
# 00:17:17,000 --> 00:17:46,000
# 感觉不好。
# 67
# 00:17:46,000 --> 00:17:48,000
# 感觉不好。
# 68
# 00:17:48,000 --> 00:18:17,000
# 非常紧。
# 69
# 00:18:17,000 --> 00:18:19,000
# 感觉不好。
# 70
# 00:18:47,000 --> 00:18:52,000
# 感觉不好。
# 71
# 00:18:52,000 --> 00:19:02,000
# 感觉不好。
# 72
# 00:19:02,000 --> 00:19:12,000
# 感觉不好。
# 73
# 00:19:12,000 --> 00:19:22,000
# 感觉不好。
# 74
# 00:19:22,000 --> 00:19:32,000
# 感觉不好。
# 75
# 00:19:32,000 --> 00:19:34,000
# 感觉不好。
# 76
# 00:19:34,000 --> 00:19:37,000
# 感觉不好。
# 77
# 00:19:37,000 --> 00:20:00,000
# 感觉不好。
# 1
# 00:00:00,000 --> 00:00:04,600
# 哦天啊。
# 2
# 00:00:04,600 --> 00:00:09,340
# 哦天啊。
# 3
# 00:00:09,340 --> 00:00:13,640
# 好多颤抖。
# 4
# 00:00:13,640 --> 00:00:16,959
# 我爱你。
# 5
# 00:00:16,959 --> 00:00:21,080
# 我爱你。
# 6
# 00:00:21,080 --> 00:00:24,420
# 我爱你。
# 7
# 00:00:24,420 --> 00:00:28,059
# 我爱你。
# 8
# 00:02:58,259 --> 00:03:00,039
# 我爱你。
# 9
# 00:03:19,220 --> 00:03:22,679
# 让我给你挠背。
# 10
# 00:03:29,059 --> 00:03:33,059
# 我太紧张了，吃不下东西。
# 11
# 00:03:51,059 --> 00:03:53,059
# 伸伸腿。
# 12
# 00:03:58,059 --> 00:04:00,059
# 我太紧张了，吃不下东西。
# 13
# 00:04:17,059 --> 00:04:19,059
# 我太紧张了，吃不下东西。
# 14
# 00:04:28,059 --> 00:04:30,059
# 我太紧张了，吃不下东西。
# 15
# 00:04:58,059 --> 00:05:00,059
# 我太紧张了，吃不下东西。
# 16
# 00:05:28,059 --> 00:05:30,059
# 我太紧张了，吃不下东西。
# 17
# 00:05:58,059 --> 00:06:00,059
# 我太紧张了，吃不下东西。
# 18
# 00:06:08,059 --> 00:06:10,059
# 你能把手放在我头上吗？
# 19
# 00:06:10,059 --> 00:06:12,059
# 你能把手放在我头上吗？
# 20
# 00:06:28,059 --> 00:06:30,059
# 我太紧张了，吃不下东西。
# 21
# 00:06:58,059 --> 00:07:00,059
# 我太紧张了，吃不下东西。
# 22
# 00:07:28,059 --> 00:07:30,059
# 我太紧张了，吃不下东西。
# 23
# 00:07:58,059 --> 00:08:00,059
# 我太紧张了，吃不下东西。
# 24
# 00:08:28,059 --> 00:08:30,059
# 我太紧张了，吃不下东西。
# 25
# 00:08:58,059 --> 00:09:00,059
# 我太紧张了，吃不下东西。
# 26
# 00:09:28,059 --> 00:09:30,059
# 我太紧张了，吃不下东西。
# 27
# 00:09:58,059 --> 00:10:00,059
# 我太紧张了，吃不下东西。
# 28
# 00:10:28,059 --> 00:10:30,059
# 我太紧张了，吃不下东西。
# 29
# 00:10:58,059 --> 00:11:00,059
# 我太紧张了，吃不下东西。
# 30
# 00:11:16,059 --> 00:11:18,059
# 我太紧张了，吃不下东西。
# 31
# 00:11:28,059 --> 00:11:30,059
# 我太紧张了，吃不下东西。
# 32
# 00:11:44,059 --> 00:11:46,059
# 我太紧张了，吃不下东西。
# 33
# 00:11:50,059 --> 00:11:52,059
# 我能进去吗？
# 34
# 00:11:52,059 --> 00:11:54,059
# 我能进去吗？
# 35
# 00:11:54,059 --> 00:11:56,059
# 我能进去吗？
# 36
# 00:11:58,059 --> 00:12:00,059
# 我能进去吗？
# 37
# 00:12:00,059 --> 00:12:02,059
# 我能进去吗？
# 38
# 00:12:02,059 --> 00:12:04,059
# 我能进去吗？
# 39
# 00:12:04,059 --> 00:12:06,059
# 我能进去吗？
# 40
# 00:12:06,059 --> 00:12:08,059
# 我能进去吗？
# 41
# 00:12:26,059 --> 00:12:28,059
# 我能进去吗？
# 42
# 00:12:36,059 --> 00:12:38,059
# 我能进去吗？
# 43
# 00:12:52,059 --> 00:12:54,059
# 我能进去吗？
# 44
# 00:13:06,059 --> 00:13:08,059
# 我能进去吗？
# 45
# 00:13:24,059 --> 00:13:26,059
# 我会把它全部吸出来。
# 46
# 00:13:26,059 --> 00:13:28,059
# 我会把它全部吸出来。
# 47
# 00:13:52,059 --> 00:13:54,059
# 我太可爱了，都害怕。
# 48
# 00:13:56,059 --> 00:13:58,059
# 它是什么味道？
# 49
# 00:13:58,059 --> 00:14:00,059
# 它是什么味道？
# 50
# 00:14:00,059 --> 00:14:02,059
# 苦的？
# 51
# 00:14:02,059 --> 00:14:04,059
# 苦的？
# 52
# 00:14:26,059 --> 00:14:28,059
# 我吃够了。
# 53
# 00:14:28,059 --> 00:14:30,059
# 我吃够了。
# 54
# 00:14:30,059 --> 00:14:32,059
# 我吃够了。
# 55
# 00:14:32,059 --> 00:14:34,059
# 我吃够了。
# 56
# 00:14:36,059 --> 00:14:38,059
# 看起来熟了。
# 57
# 00:14:38,059 --> 00:14:40,059
# 看起来熟了。
# 58
# 00:14:42,059 --> 00:14:44,059
# 结束
