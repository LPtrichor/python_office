# %%
from openai import OpenAI
import os

# os.environ['OPENAI_BASE_URL'] = 'https://www.api.rovy.me/v1'
os.environ['OPENAI_API_KEY'] = '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'

# %%
# 语音转文字
from openai import OpenAI

client = OpenAI()

audio_file = open("segment_0.mp3", "rb")
transcript = client.audio.transcriptions.create(
    model="whisper-1",
    file=audio_file,
    response_format="srt",
    language="ja",
    temperature=0,
    # prompt="",
)
print(transcript)
# Out:
# 1
# 00:00:00,000 --> 00:00:02,000
# おやすみなさい
#
# 2
# 00:00:02,000 --> 00:00:04,000
# ご視聴ありがとうございました
#
# 3
# 00:00:30,000 --> 00:00:32,000
# おやすみなさい
#
# 4
# 00:00:57,000 --> 00:00:59,000
# すみません、もう一杯お願いします
#
# 5
# 00:00:59,000 --> 00:01:01,000
# おやすみなさい
#
# 6
# 00:01:29,000 --> 00:01:31,000
# おやすみなさい
#
# 7
# 00:01:39,000 --> 00:01:41,000
# お待たせしました
#
# 8
# 00:01:41,000 --> 00:01:43,000
# すみません
#
# 9
# 00:01:59,000 --> 00:02:01,000
# おやすみなさい
#
# 10
# 00:02:07,000 --> 00:02:09,000
# こんばんは
#
# 11
# 00:02:19,000 --> 00:02:21,000
# ご注文は
#
# 12
# 00:02:21,000 --> 00:02:23,000
# いつもと同じでよろしいでしょうか
#
# 13
# 00:02:23,000 --> 00:02:25,000
# はい
#
# 14
# 00:02:25,000 --> 00:02:27,000
# かしこまりました
#
# 15
# 00:02:29,000 --> 00:02:31,000
# はい
#
# 16
# 00:02:35,000 --> 00:02:37,000
# よかったら
#
# 17
# 00:02:37,000 --> 00:02:39,000
# ありがとう
#
# 18
# 00:02:53,000 --> 00:02:55,000
# お待たせしました
#
# 19
# 00:02:55,000 --> 00:02:57,000
# ありがとうございます
#
# 20
# 00:02:57,000 --> 00:02:59,000
# はい
#
# 21
# ...

# %%
system_prompt_1 = "You are a helpful assistant for processing transcript. Your task is to translate the following text to Chinese. Additionally, pay attention to capturing the emotional exchanges and tone variations between characters, ensuring the translation is faithful to the source material while also conveying the same emotions and narrative atmosphere to an Chinese-speaking audience. Notice: the scene of the transcript  is from a Japanese Adult movie. "
from openai.types.chat import completion_create_params
def generate_corrected_transcript_1(temperature, system_prompt, text):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-16k",
        temperature=temperature,
        max_tokens=10000,
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content":  f'字幕源文件： { {transcript} }'
            }
        ],
        # response_format=completion_create_params.ResponseFormat(type="json_object")
    )
    # print(response)
    print(type(response))
    return response.choices[0].message.content

corrected_text = generate_corrected_transcript_1(0, system_prompt_1, transcript)
print(corrected_text)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[66], line 24
#      21     print(type(response))
#      22     return response.choices[0].message.content
# ---> 24 corrected_text = generate_corrected_transcript_1(0, system_prompt_1, transcript)
#      25 print(corrected_text)
#
# Cell In[66], line 4, in generate_corrected_transcript_1(temperature, system_prompt, text)
#       3 def generate_corrected_transcript_1(temperature, system_prompt, text):
# ----> 4     response = client.chat.completions.create(
#       5         model="gpt-3.5-turbo-16k",
#       6         temperature=temperature,
#       7         max_tokens=10000,
#       8         messages=[
#       9             {
#      10                 "role": "system",
#      11                 "content": system_prompt
#      12             },
#      13             {
#      14                 "role": "user",
# ...

# %%
# 存储srt文件
with open("ADN-529.srt", "w") as f:
    f.write(transcript)

# %% [markdown]
# ## 翻译音频为英语

# %% [markdown]
# ### 示例

# %%
# 音频翻译成英文
from openai import OpenAI
client = OpenAI()
filename = 'segment_0.mp3'
with open(filename, "rb") as audio_file:
    translate = client.audio.translations.create(
        model="whisper-1",
        file=audio_file,
        response_format="srt",
        # temperature=0.2,
        # prompt="Translate the following Japanese audio to English:",
    )
    # 根据音频文件名生成SRT文件名
    # srt_filename = filename.replace('.mp3', '.srt')
    print(translate)
# 存储翻译结果到SRT文件
# with open(srt_filename, "w") as f:
#     f.write(translate)
#
# print(f"Translation for {filename} saved to {srt_filename}")
# Out:
# 1
# 00:00:00,000 --> 00:00:02,000
# You
#
# 2
# 00:00:30,000 --> 00:00:32,000
# So
#
# 3
# 00:01:00,000 --> 00:01:02,000
# So
#
# 4
# 00:01:30,000 --> 00:01:32,000
# So
#
# 5
# 00:02:00,000 --> 00:02:02,000
# Good
#
# 6
# 00:02:08,000 --> 00:02:10,000
# Good evening
#
# 7
# 00:02:19,000 --> 00:02:21,000
# May I take your order?
#
# 8
# 00:02:21,000 --> 00:02:23,000
# The usual?
#
# 9
# 00:02:23,000 --> 00:02:24,000
# Yes
#
# 10
# 00:02:24,000 --> 00:02:26,000
# Thank you
#
# 11
# 00:02:30,000 --> 00:02:32,000
# Here you go
#
# 12
# 00:02:35,000 --> 00:02:37,000
# Would you like some?
#
# 13
# 00:02:38,000 --> 00:02:40,000
# Thank you
#
# 14
# 00:02:52,000 --> 00:02:54,000
# Here you go
#
# 15
# 00:02:55,000 --> 00:02:57,000
# Thank you
#
# 16
# 00:03:00,000 --> 00:03:02,000
# Here you go
#
# 17
# 00:03:16,000 --> 00:03:21,000
# I was on a date with my girlfriend
#
# 18
# 00:03:22,000 --> 00:03:26,000
# It was our 5th anniversary
#
# 19
# 00:03:26,000 --> 00:03:31,000
# ...

# %%
srt_filename = filename.replace('.mp3', '.srt')
with open(srt_filename, "w", encoding='utf-8') as f:
    print(translate)
    f.write(translate)

# %%
system_prompt = "You are a helpful assistant for processing transcript. Your task is to translate the following text to Chinese. Additionally, pay attention to capturing the emotional exchanges and tone variations between characters, ensuring the translation is faithful to the source material while also conveying the same emotions and narrative atmosphere to an Chinese-speaking audience."
from openai.types.chat import completion_create_params
def generate_corrected_transcript(temperature, system_prompt, text):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-16k",
        temperature=temperature,
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content":  text
            }
        ],
        # response_format=completion_create_params.ResponseFormat(type="json_object")
    )
    # print(response)
    print(type(response))
    return response.choices[0].message.content

corrected_text = generate_corrected_transcript(0, system_prompt, translate)
# Out:
# <class 'openai.types.chat.chat_completion.ChatCompletion'>

# %%
print(corrected_text)
# Out:
# 1
# 00:00:00,000 --> 00:00:02,000
# 你
#
# 2
# 00:00:30,000 --> 00:00:32,000
# 那么
#
# 3
# 00:01:00,000 --> 00:01:02,000
# 那么
#
# 4
# 00:01:30,000 --> 00:01:32,000
# 那么
#
# 5
# 00:02:00,000 --> 00:02:02,000
# 好
#
# 6
# 00:02:08,000 --> 00:02:10,000
# 晚上好
#
# 7
# 00:02:19,000 --> 00:02:21,000
# 可以点菜吗？
#
# 8
# 00:02:21,000 --> 00:02:23,000
# 照常吗？
#
# 9
# 00:02:23,000 --> 00:02:24,000
# 是的
#
# 10
# 00:02:24,000 --> 00:02:26,000
# 谢谢
#
# 11
# 00:02:30,000 --> 00:02:32,000
# 给你
#
# 12
# 00:02:35,000 --> 00:02:37,000
# 要吃点吗？
#
# 13
# 00:02:38,000 --> 00:02:40,000
# 谢谢
#
# 14
# 00:02:52,000 --> 00:02:54,000
# 给你
#
# 15
# 00:02:55,000 --> 00:02:57,000
# 谢谢
#
# 16
# 00:03:00,000 --> 00:03:02,000
# 给你
#
# 17
# 00:03:16,000 --> 00:03:21,000
# 我和女朋友约会
#
# 18
# 00:03:22,000 --> 00:03:26,000
# 我们五周年纪念日
#
# 19
# 00:03:26,000 --> 00:03:31,000
# 我打算向她求婚
#
# 20
# 00:03:32,000 --> 00:03:34,000
# 但她把我甩了
#
# 21
# 00:03:39,000 --> 00:03:41,000
# 我们在同一所大学
#
# 22
# 00:03:41,000 --> 00:03:44,000
# 我们是彼此的初恋
#
# ...

# %% [markdown]
# ### 批量操作

# %%
import glob

# 遍历当前目录下所有以 'segment_' 开头的 .mp3 文件
for filename in glob.glob('segment_*.mp3'):
    print(filename)

# %%
# 音频翻译成英文
from openai import OpenAI
client = OpenAI()

import glob

# 获取当前目录下所有以 'segment_' 开头的 .mp3 文件
segment_files = glob.glob('segment_*.mp3')

# 遍历文件列表
for filename in segment_files:
    with open(filename, "rb") as audio_file:
        translate = client.audio.translations.create(
            model="whisper-1",
            file=audio_file,
            response_format="srt",
        )
            # 根据音频文件名生成SRT文件名
    srt_filename = filename.replace('.mp3', '.srt')

    # 存储翻译结果到SRT文件
    with open(srt_filename, "w") as f:
        f.write(translate)

    print(f"Translation for {filename} saved to {srt_filename}")

# %%
# 存储srt文件
with open("seg1.srt", "w") as f:
    f.write(translate)
